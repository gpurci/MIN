# %% [markdown]
# Knapsack problem

# %%
import numpy as np
from pathlib import Path
import sys

# %%
LCL_PATH = str(Path().cwd())
LCL_PATH
# Out:
# '/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/KP'

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append("/home/gheorghe/Desktop/AI/manager/imshow")

def remove_modules(modules_name, *arg):
    if (modules_name in sys.modules):
        del sys.modules[modules_name]
        for key in arg:
            tmp_modules = "{}.{}".format(modules_name, key)
            del sys.modules[tmp_modules]

# %%
remove_modules("imshow")
remove_modules("builds.kp_generator")
remove_modules("builds.genetic_optimizer_KP")

from imshow import *
from builds.kp_generator import *
from builds.genetic_optimizer_KP import *

# %% [markdown]
# # Map Generator

# %%
filename = "{}/data/{}".format(LCL_PATH, "ITEMS_SECTION.csv")
kp_generator = KPGenerator()
pd_dataset   = kp_generator.read_csv(filename)
pd_dataset
# Out:
#      INDEX  PROFIT  WEIGHT  ASSIGNED_NODE_NUMBER
# 0        1     101       1                     2
# 1        2     202       2                     3
# 2        3     404       4                     4
# 3        4     202       2                     5
# 4        5     996     896                     6
# ..     ...     ...     ...                   ...
# 274    275     786     686                   276
# 275    276    1572    1372                   277
# 276    277     786     686                   278
# 277    278     566     466                   279
# 278    279     456     356                   280
#
# [279 rows x 4 columns]

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Fit one

# %%
kp = KP("KP")

# %%
kp.setParameters(
    GENERATIONS     = 100,   # numarul de generatii
    POPULATION_SIZE = 600,  # numarul populatiei
    MUTATION_RATE   = 0.085,   # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.3,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 5,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    W               = 25936,   # greutatea maxima admisibila
)
#population = None
individ, population = kp(pd_dataset, population)
# Out:
# KP, Generatia: 0, Fitness 0.452, Profit: 42031.000 Greutate: 25931.000, Max profit 23630.000, Min greutate 144021.000
# KP, Generatia: 1, Fitness 0.470, Profit: 42031.000 Greutate: 25931.000, Max profit 23931.000, Min greutate 136656.000
# Similar individs: size 241, population size: 600
# KP, Generatia: 2, Fitness 1.000, Profit: 42031.000 Greutate: 25931.000, Max profit 25082.000, Min greutate 42031.000
# KP, Generatia: 3, Fitness 0.378, Profit: 42031.000 Greutate: 25931.000, Max profit 22243.000, Min greutate 180324.000
# KP, Generatia: 4, Fitness 0.379, Profit: 42031.000 Greutate: 25931.000, Max profit 23561.000, Min greutate 179505.000
# KP, Generatia: 5, Fitness 0.371, Profit: 42031.000 Greutate: 25931.000, Max profit 22312.000, Min greutate 184459.000
# KP, Generatia: 6, Fitness 0.392, Profit: 42031.000 Greutate: 25931.000, Max profit 22588.000, Min greutate 172657.000
# Similar individs: size 22, population size: 600
# KP, Generatia: 7, Fitness 0.404, Profit: 42031.000 Greutate: 25931.000, Max profit 21994.000, Min greutate 165860.000
# KP, Generatia: 8, Fitness 0.355, Profit: 42031.000 Greutate: 25931.000, Max profit 23117.000, Min greutate 194659.000
# KP, Generatia: 9, Fitness 0.382, Profit: 42031.000 Greutate: 25931.000, Max profit 23344.000, Min greutate 177937.000
