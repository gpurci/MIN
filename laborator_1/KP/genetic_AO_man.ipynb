# %% [markdown]
# Knapsack problem

# %%
import numpy as np
from pathlib import Path
import sys

# %%
LCL_PATH = str(Path().cwd())
LCL_PATH
# Out:
# '/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/KP'

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append("/home/gheorghe/Desktop/AI/manager/imshow")

def remove_modules(modules_name, *arg):
    if (modules_name in sys.modules):
        del sys.modules[modules_name]
        for key in arg:
            tmp_modules = "{}.{}".format(modules_name, key)
            del sys.modules[tmp_modules]

# %%
remove_modules("imshow")
remove_modules("builds.kp_generator")
remove_modules("builds.genetic_optimizer_KP")

from imshow import *
from builds.kp_generator import *
from builds.genetic_optimizer_KP import *

# %% [markdown]
# # Map Generator

# %%
filename = "{}/data/{}".format(LCL_PATH, "ITEMS_SECTION.csv")
kp_generator = KPGenerator()
pd_dataset   = kp_generator.read_csv(filename)
pd_dataset
# Out:
#      INDEX  PROFIT  WEIGHT  ASSIGNED_NODE_NUMBER
# 0        1     101       1                     2
# 1        2     202       2                     3
# 2        3     404       4                     4
# 3        4     202       2                     5
# 4        5     996     896                     6
# ..     ...     ...     ...                   ...
# 274    275     786     686                   276
# 275    276    1572    1372                   277
# 276    277     786     686                   278
# 277    278     566     466                   279
# 278    279     456     356                   280
#
# [279 rows x 4 columns]

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Fit one

# %%
kp = KP("KP")

# %%
kp.setParameters(
    GENERATIONS     = 100,   # numarul de generatii
    POPULATION_SIZE = 600,  # numarul populatiei
    MUTATION_RATE   = 0.085,   # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.3,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 5,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    W               = 25936,   # greutatea maxima admisibila
)
#population = None
individ, population = kp(pd_dataset, population)
# Out:
# KP, Generatia: 0, Fitness 0.953, Profit: 164581.000 Greutate: 136581.000, Max profit 124614.000, Min greutate 180663.000
# KP, Generatia: 1, Fitness 0.963, Profit: 162020.000 Greutate: 134020.000, Max profit 123754.000, Min greutate 174139.000
# KP, Generatia: 2, Fitness 0.977, Profit: 160341.000 Greutate: 131841.000, Max profit 121275.000, Min greutate 167605.000
# KP, Generatia: 3, Fitness 0.981, Profit: 157649.000 Greutate: 130049.000, Max profit 121377.000, Min greutate 163796.000
# KP, Generatia: 4, Fitness 0.977, Profit: 156235.000 Greutate: 128635.000, Max profit 119963.000, Min greutate 163618.000
# KP, Generatia: 5, Fitness 0.979, Profit: 154465.000 Greutate: 127165.000, Max profit 118235.000, Min greutate 161131.000
# KP, Generatia: 6, Fitness 0.974, Profit: 152531.000 Greutate: 124931.000, Max profit 116808.000, Min greutate 160554.000
# KP, Generatia: 7, Fitness 0.979, Profit: 150864.000 Greutate: 122764.000, Max profit 116064.000, Min greutate 156977.000
# KP, Generatia: 8, Fitness 0.980, Profit: 148432.000 Greutate: 121232.000, Max profit 114291.000, Min greutate 154534.000
