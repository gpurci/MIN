# %% [markdown]
# Description ????????????????????????

# %%
import numpy as np
from pathlib import Path
import sys

# %%
LCL_PATH  = str(Path().cwd())
SHOW_PATH = str(Path(LCL_PATH).parent.parent)
PARENT_PATH = str(Path(LCL_PATH).parent/"GeneticAlgoritmMethods/my_code")
print("local path:\t{}\nshow path:\t{}\nparent_path:\t{}".format(LCL_PATH, SHOW_PATH, PARENT_PATH))
# Out:
# local path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP
# show path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura
# parent_path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append(PARENT_PATH)
sys.path.append(SHOW_PATH)

def remove_modules(modules_name, *arg):
    if (modules_name in sys.modules):
        del sys.modules[modules_name]
        for key in arg:
            tmp_modules = "{}.{}".format(modules_name, key)
            del sys.modules[tmp_modules]

# %%
remove_modules("imshow")
remove_modules("algoritm_genetic")
remove_modules("builds.tsp_generator")
remove_modules("builds.genetic_optimizer_TSP")
remove_modules("builds.genetic_optimizer_TSP_groups")

from imshow import *
from algoritm_genetic import *
from builds.tsp_generator import *
from builds.genetic_optimizer_TSP import *
from builds.genetic_optimizer_TSP_groups import *

# %% [markdown]
# # Map Generator

# %%
filename = "{}/data/{}".format(LCL_PATH, "distances.csv")
tsp_generator = TSPGenerator()
pd_dataset    = tsp_generator.read_csv(filename)
pd_dataset
# Out:
#      INDEX    X    Y
# 0        1  288  149
# 1        2  288  129
# 2        3  270  133
# 3        4  256  141
# 4        5  256  157
# ..     ...  ...  ...
# 275    276  236  145
# 276    277  246  141
# 277    278  252  125
# 278    279  260  129
# 279    280  280  133
#
# [280 rows x 3 columns]

# %%
map_of_distance = tsp_generator()
map_of_distance.shape
# Out:
# (280, 280)

# %%
map_img = tsp_generator.putRoutesOnMap([0])
image_show_wait(map_img)

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Fit Config

# %%
GeneticAlgorithm().help()
# Out:
# 'nume': numele obiectului
# 'extern_commnad_file': numele fisierului in care vor fi adaugate comenzile externe, (oprire fortata = stop=True)
# 'metric': Metrics:
#         metode de config: 'TSP'
# 'init_population': InitPopulation:
#         metode de config: 'vecin', 'TSP_aleator'
# 'fitness': Fitness:
#         metode de config: 'TSP_f1score', 'TSP_norm',
# 'select_parent': {'select_parent1': 'select_parent2'}: SelectParent:
#         metode de config: 'choice', 'roata', 'turneu', 'turneu_choice', 'crescator', 'mixt'
# 'crossover': Crossover:
#         metode de config: 'diff', 'split', 'perm_sim', 'mixt',
# 'mutate': Mutate:
#         metode de config: 'inversion', 'scramble', 'swap', 'roll', 'insertion', 'rool_sim', 'perm_sim', 'flip_sim', 'mixt',
# 'callback': Callback:
#         metode de config: 'filename'

# %%
filename_logs = "{}/logs/history.csv".format(LCL_PATH)
extern_commnad_file ="{}/extern_command.cmd".format(LCL_PATH)
tsp = GeneticAlgorithm(
    name="TSP",
    extern_commnad_file=extern_commnad_file,
    metric="TSP",
    init_population="TSP_aleator",
    fitness="TSP_f1score",
    select_parent= {"select_parent1":"turneu", "select_parent2":"turneu_choice"},
    crossover="mixt",
    mutate="mixt",
    callback=filename_logs
                      )
tsp.setDataset(map_of_distance)
tsp.setParameters(
    GENOME_LENGTH=map_of_distance.shape[0], # numarul de alele
    )
print(tsp)
# Out:
# Utilizezi metoda: TSP, datele de antrenare trebuie sa corespunda metodei de calcul a metricilor!!!
# Name: TSP
#
#     GENERATIONS     = 500
#     POPULATION_SIZE = 100
#     GENOME_LENGTH   = 280
#     MUTATION_RATE   = 0.01
#     CROSSOVER_RATE  = 0.5
#     SELECT_RATE     = 0.8
#     ELITE_SIZE      = 5
# Configs:
# 	metric: TSP
# 	init_population: TSP_aleator
# 	fitness: TSP_f1score
# 	select_parent: {'select_parent1': 'turneu', 'select_parent2': 'turneu_choice'}
# 	crossover: mixt
# 	mutate: mixt
# 	callback: /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP/logs/history.csv

# %%
tsp.setParameters(
    GENERATIONS     = 5000, # numarul de generatii
    POPULATION_SIZE = 1000, # numarul populatiei
    MUTATION_RATE   = 0.05,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.99,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.99,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 50,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
#print(tsp)
population = None
routes, population = tsp(population)
# Out:
# Name:TSP, Generatia: 0, score: 3769.243, best_fitness: 0.994,
# Name:TSP, Generatia: 1, score: 3769.243, best_fitness: 0.994,
# Name:TSP, Generatia: 2, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 3, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 4, score: 3769.243, best_fitness: 1.0,
# evolutionScores {'score': np.float64(3769.2428687284255), 'best_fitness': np.float64(0.9999999500000026)}
# Name:TSP, Generatia: 5, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 6, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 37, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 38, score: 3769.243, best_fitness: 0.998,
# Name:TSP, Generatia: 39, score: 3769.243, best_fitness: 0.999,
# evolutionScores {'score': np.float64(3769.2428687284255), 'best_fitness': np.float64(0.9942404868165235)}
# Name:TSP, Generatia: 40, score: 3769.243, best_fitness: 0.994,
# Name:TSP, Generatia: 41, score: 3769.243, best_fitness: 0.998,
# Name:TSP, Generatia: 42, score: 3769.243, best_fitness: 0.999,
# Name:TSP, Generatia: 43, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 44, score: 3769.243, best_fitness: 1.0,
# evolutionScores {'score': np.float64(3769.2428687284255), 'best_fitness': np.float64(0.999688835435027)}
# Name:TSP, Generatia: 45, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 46, score: 3769.243, best_fitness: 1.0,
# Name:TSP, Generatia: 47, score: 3769.243, best_fitness: 0.999,
# Name:TSP, Generatia: 48, score: 3769.243, best_fitness: 1.0,

# %%
map_img = tsp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)

# %% [markdown]
# ## Fit TSP

# %%
tsp = TSP()

# %%
tsp.setParameters(
    GENERATIONS     = 500, # numarul de generatii
    POPULATION_SIZE = 400, # numarul populatiei
    GENOME_LENGTH   = 4, # numarul de alele
    MUTATION_RATE   = 0.01,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.8,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 15,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
#population = None
routes, population = tsp(map_of_distance, population)

# %%
map_img = tsp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)

# %% [markdown]
# ## Fit Group TSP

# %%
lst_tsp = [TSP("TSP_{}".format(i)) for i in range(6)]
group_tsp = GroupTSP(lst_tsp)

# %%
group_tsp.setParameters(
    GENERATIONS     = 5000, # numarul de generatii
    POPULATION_SIZE = 300, # numarul populatiei
    MUTATION_RATE   = 0.01,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.8,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 15,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
routes = group_tsp(map_of_distance)

# %%
map_img = tsp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)

# %%
populations = group_tsp.populations

# %%
group_tsp.populations = populations
