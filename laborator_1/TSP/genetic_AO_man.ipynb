# %% [markdown]
# Description ????????????????????????

# %%
import numpy as np
from pathlib import Path
import sys

# %%
LCL_PATH = str(Path().cwd())
LCL_PATH
# Out:
# '/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP'

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append("/home/gheorghe/Desktop/AI/manager/imshow")

def remove_modules(modules_name, *arg):
    if (modules_name in sys.modules):
        del sys.modules[modules_name]
        for key in arg:
            tmp_modules = "{}.{}".format(modules_name, key)
            del sys.modules[tmp_modules]

# %%
remove_modules("imshow")
remove_modules("builds.tsp_generator")
remove_modules("builds.genetic_optimizer_TSP")
remove_modules("builds.genetic_optimizer_TSP_groups")

from imshow import *
from builds.tsp_generator import *
from builds.genetic_optimizer_TSP import *
from builds.genetic_optimizer_TSP_groups import *

# %% [markdown]
# # Map Generator

# %%
filename = "{}/data/{}".format(LCL_PATH, "distances.csv")
tsp_generator = TSPGenerator()
pd_dataset    = tsp_generator.read_csv(filename)
pd_dataset
# Out:
#      INDEX    X    Y
# 0        1  288  149
# 1        2  288  129
# 2        3  270  133
# 3        4  256  141
# 4        5  256  157
# ..     ...  ...  ...
# 275    276  236  145
# 276    277  246  141
# 277    278  252  125
# 278    279  260  129
# 279    280  280  133
#
# [280 rows x 3 columns]

# %%
map_of_distance = tsp_generator()

# %%
map_img = tsp_generator.putRoutesOnMap([0])
image_show_wait(map_img)
# Out:
# Key 32

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Fit TSP

# %%
tsp = TSP()

# %%
tsp.setParameters(
    GENERATIONS     = 500, # numarul de generatii
    POPULATION_SIZE = 400, # numarul populatiei
    GENOME_LENGTH   = 4, # numarul de alele
    MUTATION_RATE   = 0.01,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.8,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 15,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
#population = None
routes, population = tsp(map_of_distance, population)
# Out:
# Similar individs: size 292, population size: 400
# , Generatia: 0, Distanta: 6411.229, Best fitness 0.940, Distanta min: 5710.231, Min distance 5710.231
# , Generatia: 1, Distanta: 6411.229, Best fitness 0.957, Distanta min: 5894.779, Min distance 5894.779
# , Generatia: 2, Distanta: 6411.229, Best fitness 0.948, Distanta min: 5791.202, Min distance 5791.202
# , Generatia: 3, Distanta: 6411.229, Best fitness 0.954, Distanta min: 5853.634, Min distance 5853.634
# , Generatia: 4, Distanta: 6411.229, Best fitness 0.965, Distanta min: 0.000, Min distance 5988.257
# Similar individs: size 317, population size: 400
# , Generatia: 5, Distanta: 6411.229, Best fitness 0.972, Distanta min: 0.000, Min distance 6068.511
# , Generatia: 6, Distanta: 6411.229, Best fitness 0.967, Distanta min: 6004.373, Min distance 6004.373
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 11
#       1 tsp.setParameters(
#       2     GENERATIONS     = 500, # numarul de generatii
#       3     POPULATION_SIZE = 400, # numarul populatiei
#    (...)      8     ELITE_SIZE      = 15,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
#       9     )
#      10 #population = None
# ---> 11 routes, population = tsp(map_of_distance, population)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP/builds/genetic_optimizer_TSP.py:115, in TSP.__call__(self, map_distances, population)
#     113 args_elite     = self.getArgElite(fitness_values)
#     114 # calculare metrici
# --> 115 best_individ, best_fitness, best_distance, best_number_city, distance, number_city = self.clcMetrics(population, fitness_values)
#     116 self.evolutionMonitor(best_distance)
#     117 #self.log(population, fitness_values, args_elite, elite_individs, best_distance)
#     118 # adaugare stres in populatie atunci cand lipseste progresul
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP/builds/genetic_optimizer_TSP.py:215, in TSP.clcMetrics(self, population, fitness_values)
#     213 distance    = self.getBestDistance(population)
#     214 # selectarea celui mai mare numar de orase din intreaga populatie
# --> 215 number_city = self.getBestNumberCities(population)
#     217 return best_individ, best_fitness, best_distance, best_number_city, distance, number_city
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP/builds/genetic_optimizer_TSP.py:587, in TSP.getBestNumberCities(self, population)
#     585 def getBestNumberCities(self, population):
#     586     """Calculeaza cel mai mare numar de orase din intreaga populatie"""
# --> 587     number_city = self.getNumberCities(population)
#     588     return number_city.max()
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP/builds/genetic_optimizer_TSP.py:622, in TSP.getNumberCities(self, population)
#     620 def getNumberCities(self, population):
#     621     """Calculeaza numarul de orase pentru fiecare individ din populatie"""
# --> 622     return np.apply_along_axis(self.getIndividNumberCities,
#     623                                     axis=1,
#     624                                     arr=population)
#
# File ~/venvs/torch_env/lib/python3.12/site-packages/numpy/lib/_shape_base_impl.py:409, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     407 buff[ind0] = res
#     408 for ind in inds:
# --> 409     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     411 res = transpose(buff, buff_permute)
#     412 return conv.wrap(res)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TSP/builds/genetic_optimizer_TSP.py:573, in TSP.getIndividNumberCities(self, individ)
#     572 def getIndividNumberCities(self, individ):
# --> 573     return np.unique(individ[:-1], return_index=False, return_inverse=False, return_counts=False, axis=None).shape[0]
#
# File ~/venvs/torch_env/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:288, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     285 if axis is None:
#     286     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     287                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
# --> 288     return _unpack_tuple(ret)
#     290 # axis was specified and not None
#     291 try:
#
# File ~/venvs/torch_env/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:132, in _unpack_tuple(x)
#     127     np.subtract(ary[1:], ary[:-1], result[l_begin:l_begin + l_diff])
#     129     return conv.wrap(result)
# --> 132 def _unpack_tuple(x):
#     133     """ Unpacks one-element tuples for use as return values """
#     134     if len(x) == 1:
#
# KeyboardInterrupt:

# %%
map_img = tsp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)
# Out:
# Key 32

# %% [markdown]
# ## Fit Group TSP

# %%
lst_tsp = [TSP("TSP_{}".format(i)) for i in range(6)]
group_tsp = GroupTSP(lst_tsp)

# %%
group_tsp.setParameters(
    GENERATIONS     = 5000, # numarul de generatii
    POPULATION_SIZE = 300, # numarul populatiei
    MUTATION_RATE   = 0.01,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.8,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 15,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
routes = group_tsp(map_of_distance)

# %%
map_img = tsp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)

# %%
populations = group_tsp.populations

# %%
group_tsp.populations = populations
