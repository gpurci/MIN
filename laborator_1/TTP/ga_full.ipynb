# %% [markdown]
# # GA_FULL: Full method: GA + multi-repair + stress + VND (TSP+KP LS)

# %%
import numpy as np
from pathlib import Path
from builds.ttp_generator import *
import sys

LCL_PATH  = str(Path().cwd())
ROOT_PATH = str(Path(LCL_PATH).parent.parent)
EXTERN_CMD_PATH = str(Path(ROOT_PATH))
GENERIC_PATH    = str(Path(ROOT_PATH) / "GeneticAlgorithmManager/my_code")
SPECIFIC_PATH   = str(Path(ROOT_PATH) / "extension")

print("""
root path:\t{}
local path:\t{}
generic_path:\t{}
project_specific_path:\t{}
extern_cmd_path:\t{}""".format(ROOT_PATH, LCL_PATH, GENERIC_PATH, SPECIFIC_PATH, EXTERN_CMD_PATH))

sys.path.append(ROOT_PATH)
sys.path.append(LCL_PATH)
sys.path.append(GENERIC_PATH)
sys.path.append(SPECIFIC_PATH)

ttp_generator = TTPGenerator("{}/data".format(LCL_PATH))
dataset = ttp_generator(
    nodes_file="NODE_COORD_SECTION.csv",
    items_file="ITEMS_SECTION.csv",
)
# Out:
# root path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN
# local path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\laborator_1\TTP
# generic_path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\GeneticAlgorithmManager\my_code
# project_specific_path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension
# extern_cmd_path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN

# %%
# %% [code]
from builder_ttp import (
    build_ttp_ga,
    BASE_DATASET,
    GA_FULL,
)

dataset.update(BASE_DATASET)

cfg = GA_FULL

extern_command_file = "{}/extern_command.cmd".format(EXTERN_CMD_PATH)
log_file = "{}/logs/{}_history.csv".format(LCL_PATH, cfg["id"])

ttp = build_ttp_ga(dataset, cfg, extern_command_file, log_file)

print("Config ID:", cfg["id"])
print(cfg["description"])
print("GA params:", {k: cfg[k] for k in ["population_size", "generations", "mutation_rate", "crossover_rate"]})

best_individ = ttp()
best_individ
# Out:
# setParameters: {'GENOME_LENGTH': 280, 'GENERATIONS': 150, 'POPULATION_SIZE': 400, 'MUTATION_RATE': 0.08, 'CROSSOVER_RATE': 0.7, 'SELECT_RATE': 0.5, 'W': 25936, 'v_min': 0.1, 'v_max': 1.0, 'R': 5.61, 'ELITE_SIZE': 40, 'ELITE_FREQ': 8}
# Config ID: ga_full
# Full method: GA + multi-repair + stress + VND (TSP+KP LS)
# GA params: {'population_size': 400, 'generations': 150, 'mutation_rate': 0.08, 'crossover_rate': 0.7}
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 0, score: 2476.844, profit: 30019.0, time: 4909.475, distance: 2770.0, weight: 25919.0, best_fitness: 664957.178,
# Name:ga_full, Generatia: 1, score: 3336.118, profit: 26734.0, time: 4170.745, distance: 2711.0, weight: 22734.0, best_fitness: 1.0000000000000033e+18,
# Name:ga_full, Generatia: 2, score: 7502.528, profit: 34627.0, time: 4835.022, distance: 2657.0, weight: 25827.0, best_fitness: 401752.349,
# Name:ga_full, Generatia: 3, score: 9174.022, profit: 37994.0, time: 5137.251, distance: 3067.0, weight: 25594.0, best_fitness: 299519.187,
# Name:ga_full, Generatia: 4, score: 9680.651, profit: 32534.0, time: 4073.681, distance: 2657.0, weight: 23434.0, best_fitness: 396841.164,
# Name:ga_full, Generatia: 5, score: 10499.541, profit: 33678.0, time: 4131.633, distance: 2657.0, weight: 25278.0, best_fitness: 416756.757,
# Name:ga_full, Generatia: 6, score: 11777.079, profit: 36400.0, time: 4389.112, distance: 2657.0, weight: 25500.0, best_fitness: 409964.212,
# Name:ga_full, Generatia: 7, score: 12689.433, profit: 36838.0, time: 4304.557, distance: 2700.0, weight: 24038.0, best_fitness: 419613.805,
# Name:ga_full, Generatia: 8, score: 13024.486, profit: 36838.0, time: 4244.833, distance: 2650.0, weight: 24038.0, best_fitness: 416900.244,
# Name:ga_full, Generatia: 9, score: 13992.531, profit: 37115.0, time: 4121.652, distance: 2700.0, weight: 25815.0, best_fitness: 421811.329,
# Name:ga_full, Generatia: 10, score: 14276.016, profit: 37582.0, time: 4154.364, distance: 2650.0, weight: 25182.0, best_fitness: 191750.13,
# Name:ga_full, Generatia: 11, score: 14995.981, profit: 38701.0, time: 4225.494, distance: 2657.0, weight: 25301.0, best_fitness: 100853.509,
# Name:ga_full, Generatia: 12, score: 15002.563, profit: 39185.0, time: 4310.595, distance: 2643.0, weight: 25885.0, best_fitness: 43447.756,
# Name:ga_full, Generatia: 13, score: 15362.956, profit: 38849.0, time: 4186.461, distance: 2657.0, weight: 25649.0, best_fitness: 38619.08,
# Name:ga_full, Generatia: 14, score: 15460.567, profit: 38886.0, time: 4175.657, distance: 2643.0, weight: 25886.0, best_fitness: 43061.372,
# Name:ga_full, Generatia: 15, score: 15625.147, profit: 39759.0, time: 4301.935, distance: 2657.0, weight: 25859.0, best_fitness: 26131.229,
# Name:ga_full, Generatia: 16, score: 15625.147, profit: 39759.0, time: 4301.935, distance: 2657.0, weight: 25859.0, best_fitness: 34417.395,
# Name:ga_full, Generatia: 17, score: 15886.689, profit: 38754.0, time: 4076.17, distance: 2657.0, weight: 25754.0, best_fitness: 30300.575,
# Name:ga_full, Generatia: 18, score: 16036.859, profit: 38754.0, time: 4049.401, distance: 2632.0, weight: 25754.0, best_fitness: 31923.434,
# Name:ga_full, Generatia: 19, score: 16059.079, profit: 38972.0, time: 4084.3, distance: 2657.0, weight: 25772.0, best_fitness: 38083.192,
# Name:ga_full, Generatia: 20, score: 16521.772, profit: 38778.0, time: 3967.242, distance: 2643.0, weight: 25778.0, best_fitness: 18000.275,
# Name:ga_full, Generatia: 21, score: 16521.772, profit: 38778.0, time: 3967.242, distance: 2643.0, weight: 25778.0, best_fitness: 49454.749,
# Name:ga_full, Generatia: 22, score: 16521.772, profit: 38778.0, time: 3967.242, distance: 2643.0, weight: 25778.0, best_fitness: 37320.086,
# Name:ga_full, Generatia: 23, score: 16521.772, profit: 38778.0, time: 3967.242, distance: 2643.0, weight: 25778.0, best_fitness: 36768.849,
# Name:ga_full, Generatia: 24, score: 16521.772, profit: 38778.0, time: 3967.242, distance: 2643.0, weight: 25778.0, best_fitness: 28180.135,
# Name:ga_full, Generatia: 25, score: 16664.236, profit: 39161.0, time: 4010.118, distance: 2632.0, weight: 25861.0, best_fitness: 28510.049,
# Name:ga_full, Generatia: 26, score: 16721.003, profit: 39189.0, time: 4004.991, distance: 2632.0, weight: 25889.0, best_fitness: 142640.979,
# Name:ga_full, Generatia: 27, score: 16721.003, profit: 39189.0, time: 4004.991, distance: 2632.0, weight: 25889.0, best_fitness: 37379.79,
# Name:ga_full, Generatia: 28, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 30645.423,
# Name:ga_full, Generatia: 29, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 37965.306,
# Name:ga_full, Generatia: 30, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 30125.564,
# Name:ga_full, Generatia: 31, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 31795.53,
# Name:ga_full, Generatia: 32, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 26789.282,
# Name:ga_full, Generatia: 33, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 175729.067,
# Name:ga_full, Generatia: 34, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 301765.337,
# Name:ga_full, Generatia: 35, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 301765.337,
# Name:ga_full, Generatia: 36, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 39663.651,
# Name:ga_full, Generatia: 37, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 33302.241,
# Name:ga_full, Generatia: 38, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 200481.469,
# Name:ga_full, Generatia: 39, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 102857.875,
# Name:ga_full, Generatia: 40, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 52933.291,
# Name:ga_full, Generatia: 41, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 42701.895,
# Name:ga_full, Generatia: 42, score: 16931.923, profit: 38522.0, time: 3848.499, distance: 2632.0, weight: 25922.0, best_fitness: 112481.922,
# Name:ga_full, Generatia: 43, score: 17239.619, profit: 39650.0, time: 3994.72, distance: 2632.0, weight: 25650.0, best_fitness: 57482.475,
# Name:ga_full, Generatia: 44, score: 17239.619, profit: 39650.0, time: 3994.72, distance: 2632.0, weight: 25650.0, best_fitness: 47562.9,
# Name:ga_full, Generatia: 45, score: 17239.619, profit: 39650.0, time: 3994.72, distance: 2632.0, weight: 25650.0, best_fitness: 50870.378,
# Name:ga_full, Generatia: 46, score: 17321.839, profit: 39201.0, time: 3900.029, distance: 2632.0, weight: 25801.0, best_fitness: 61314.805,
# Name:ga_full, Generatia: 47, score: 17357.783, profit: 39879.0, time: 4014.477, distance: 2632.0, weight: 25879.0, best_fitness: 45591.525,
# Name:ga_full, Generatia: 48, score: 17433.457, profit: 39839.0, time: 3993.858, distance: 2632.0, weight: 25839.0, best_fitness: 35892.292,
# Name:ga_full, Generatia: 49, score: 17667.108, profit: 39927.0, time: 3967.895, distance: 2632.0, weight: 25927.0, best_fitness: 37982.503,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 50, score: 17667.108, profit: 39927.0, time: 3967.895, distance: 2632.0, weight: 25927.0, best_fitness: 31715.866,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 51, score: 17498.066, profit: 39870.0, time: 3987.867, distance: 2632.0, weight: 25870.0, best_fitness: 791239.844,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 52, score: 17433.457, profit: 39839.0, time: 3993.858, distance: 2632.0, weight: 25839.0, best_fitness: 1034352.352,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 53, score: 15581.244, profit: 36875.0, time: 3795.678, distance: 2632.0, weight: 23575.0, best_fitness: 1032500.139,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 54, score: 11015.162, profit: 33536.0, time: 4014.41, distance: 2632.0, weight: 23936.0, best_fitness: 586419.964,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 55, score: 7671.031, profit: 36430.0, time: 5126.376, distance: 3252.0, weight: 22730.0, best_fitness: 992860.963,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_full, Generatia: 56, score: 6007.451, profit: 41763.0, time: 6373.538, distance: 2724.0, weight: 25663.0, best_fitness: 699440.977,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      18 print(cfg["description"])
#      19 print("GA params:", {k: cfg[k] for k in ["population_size", "generations", "mutation_rate", "crossover_rate"]})
# ---> 21 best_individ = ttp()
#      22 best_individ
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\GeneticAlgorithmManager\my_code\algoritm_genetic.py:111, in GeneticAlgorithm.__call__(self)
#     109 scores = self.metrics.getScore(self.__genoms, fitness_values)
#     110 # adaugare stres in populatie atunci cand lipseste progresul
# --> 111 self.stres(self.__genoms, scores)
#     112 # afisare metrici
#     113 self.showMetrics(generation, scores)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\GeneticAlgorithmManager\my_code\stres.py:15, in Stres.__call__(self, genoms, scores)
#      14 def __call__(self, genoms, scores):
# ---> 15     return self._extern_fn(genoms, scores)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\stres\my_code\stres_ttp_MATEI.py:400, in StresTTP.__call__(self, genoms, scores)
#     397     self._shake_population(genoms, scores)
#     398 else:
#     399     # Strong plateau ⇒ partial restart using hybrid init.
# --> 400     self._partial_restart(genoms, scores)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\stres\my_code\stres_ttp_MATEI.py:255, in StresTTP._partial_restart(self, genoms, scores)
#     252     return
#     254 # 1) create full new population via hybrid init
# --> 255 self.init_population(n, genoms)
#     256 pop_new = genoms.population()
#     258 # 2) overwrite the first len(keep_idx) individuals with the kept ones
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\init_population\my_code\init_hybrid_population_MATEI.py:49, in InitPopulationHybrid.__call__(self, size, genoms)
#      48 def __call__(self, size, genoms=None):
# ---> 49     self.__fn(size, genoms=genoms, **self.__configs)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\init_population\my_code\init_hybrid_population_MATEI.py:118, in InitPopulationHybrid.initPopulationHybrid(self, size, genoms, lambda_time, vmax, vmin, Wmax, seed)
#     115     r = tabu2(None, None, r)  # tabu 2-opt
#     117 elif choice < 0.90:
# --> 118     r = vnd(None, None, r)    # simple VND
#     120 else:
#     121     # Forced diversity
#     122     r = np.random.permutation(self.GENOME_LENGTH)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\vnd.py:68, in VND.__call__(self, p1, p2, route, **call_cfg)
#      66     new_route = op.twoOptLS(cur)
#      67 else:
# ---> 68     new_route = op(p1, p2, cur)
#      70 new_len = self._route_len(new_route, dist)
#      72 if new_len + 1e-12 < cur_len:
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\or_opt.py:66, in OrOpt.__call__(self, p1, p2, route, **call_configs)
#      64 cfg = dict(self.__configs)
#      65 cfg.update(call_configs)
# ---> 66 return self.__fn(p1, p2, route, **cfg)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\or_opt.py:221, in OrOpt.orOptRestrict(self, p1, p2, route, block_max, iters, k_candidates, sample_per_iter, seed)
#     219 j = j_pos % m
#     220 delta = self._delta_relocate(cur, i, L, j)
# --> 221 if delta < best_delta:
#     222     best_delta = delta
#     223     best_move = (i, L, j)
#
# KeyboardInterrupt:
