# %% [markdown]
# Travelling salesman problem
# The travelling salesman problem is one of the classic NPhard optimization problems. In this problem, there are n cities
# and the distances between the cities are given by a distance
# matrix D={dij} (dij the distance between city i and j). There is
# a salesman who must visit each city exactly once and
# minimize the time of the complete tour. It is assumed that the
# speed of the salesman is constant (vc) and he tries to minimize
# the time of the tour**3.
# The objective function is given by:
# f(x)=k=1∑n−1​txk​,xk+1​​+txn​,x1​​.

# %%
import numpy as np
from pathlib import Path
import sys

# %%
LCL_PATH  = str(Path().cwd())
SHOW_PATH = str(Path(LCL_PATH).parent.parent)
PARENT_PATH = str(Path(LCL_PATH).parent/"GeneticAlgoritmMethods/my_code")
print("local path:\t{}\nshow path:\t{}\nparent_path:\t{}".format(LCL_PATH, SHOW_PATH, PARENT_PATH))
# Out:
# local path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP
# show path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura
# parent_path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append(PARENT_PATH)
sys.path.append(SHOW_PATH)

def remove_modules(modules_name, *arg):
    if (modules_name in sys.modules):
        del sys.modules[modules_name]
        for key in arg:
            tmp_modules = "{}.{}".format(modules_name, key)
            del sys.modules[tmp_modules]

# %%
remove_modules("imshow")
remove_modules("algoritm_genetic")
remove_modules("builds.ttp_generator")

from imshow import *
from algoritm_genetic import *
from builds.ttp_generator import *

# %% [markdown]
# # Map Generator

# %%
ttp_generator = TTPGenerator("{}/data".format(LCL_PATH))
dataset = ttp_generator(nodes_file="NODE_COORD_SECTION.csv",
                        items_file="ITEMS_SECTION.csv")
dataset
# Out:
# {'GENOME_LENGTH': 280,
#  'distance': array([[ 0., 20., 24., ..., 43., 34., 18.],
#         [20.,  0., 18., ..., 36., 28.,  9.],
#         [24., 18.,  0., ..., 20., 11., 10.],
#         ...,
#         [43., 36., 20., ...,  0.,  9., 29.],
#         [34., 28., 11., ...,  9.,  0., 20.],
#         [18.,  9., 10., ..., 29., 20.,  0.]], shape=(280, 280)),
#  'coords': array([[288, 149],
#         [288, 129],
#         [270, 133],
#         [256, 141],
#         [256, 157],
#         [246, 157],
#         [236, 169],
#         [228, 169],
#         [228, 161],
#         [220, 169],
#         [212, 169],
#         [204, 169],
#         [196, 169],
#         [188, 169],
#         [196, 161],
#         [188, 145],
#         [172, 145],
#         [164, 145],
#         [156, 145],
#         [148, 145],
#         [140, 145],
#         [148, 169],
#         [164, 169],
#         [172, 169],
#         [156, 169],
#         [140, 169],
#         [132, 169],
#         [124, 169],
#         [116, 161],
#         [104, 153],
#         [104, 161],
#         [104, 169],
#         [ 90, 165],
#         [ 80, 157],
#         [ 64, 157],
#         [ 64, 165],
#         [ 56, 169],
#         [ 56, 161],
#         [ 56, 153],
#         [ 56, 145],
#         [ 56, 137],
#         [ 56, 129],
#         [ 56, 121],
#         [ 40, 121],
#         [ 40, 129],
#         [ 40, 137],
#         [ 40, 145],
#         [ 40, 153],
#         [ 40, 161],
#         [ 40, 169],
#         [ 32, 169],
#         [ 32, 161],
#         [ 32, 153],
#         [ 32, 145],
#         [ 32, 137],
#         [ 32, 129],
#         4.080e+02, 8.160e+02, 4.080e+02, 5.940e+02, 1.188e+03, 2.376e+03,
#         1.188e+03, 2.260e+02, 4.520e+02, 9.040e+02, 2.260e+02, 4.520e+02,
#         9.210e+02, 5.370e+02, 1.074e+03, 2.148e+03, 1.120e+02, 1.120e+02,
#         9.590e+02, 1.918e+03, 2.877e+03, 3.920e+02, 3.920e+02, 7.090e+02,
#         1.418e+03, 2.836e+03, 9.400e+02, 1.880e+03, 9.430e+02, 1.886e+03,
#         3.772e+03, 7.900e+01, 7.900e+01, 9.220e+02, 1.844e+03, 1.844e+03,
#         3.610e+02, 9.470e+02, 1.894e+03, 9.470e+02, 8.610e+02, 1.722e+03,
#         3.444e+03, 2.583e+03, 9.370e+02, 1.874e+03, 3.748e+03, 2.811e+03,
#         7.540e+02, 1.508e+03, 2.262e+03, 8.720e+02, 6.360e+02, 6.360e+02,
#         4.590e+02, 9.180e+02, 1.836e+03, 1.377e+03, 3.900e+02, 3.900e+02,
#         1.410e+02, 2.820e+02, 4.230e+02, 1.110e+02, 2.220e+02, 4.440e+02,
#         3.330e+02, 5.880e+02, 1.176e+03, 5.880e+02, 6.000e+00, 6.000e+00,
#         1.550e+02, 3.100e+02, 6.200e+02, 4.650e+02, 7.230e+02, 1.446e+03,
#         2.892e+03, 1.446e+03, 7.230e+02, 1.446e+03, 2.892e+03, 2.169e+03,
#         6.670e+02, 1.334e+03, 1.334e+03, 8.290e+02, 1.658e+03, 3.316e+03,
#         8.290e+02, 4.870e+02, 9.740e+02, 9.740e+02, 5.900e+02, 1.180e+03,
#         2.360e+03, 1.180e+03, 3.700e+02, 7.400e+02, 1.480e+03, 8.230e+02,
#         1.646e+03, 3.292e+03, 8.230e+02, 1.730e+02, 3.460e+02, 5.600e+01,
#         9.770e+02, 1.954e+03, 2.931e+03, 6.810e+02, 1.362e+03, 2.043e+03,
#         6.890e+02, 1.378e+03, 2.756e+03, 6.890e+02, 9.330e+02, 1.866e+03,
#         2.799e+03, 8.090e+02, 1.618e+03, 5.870e+02, 1.174e+03, 6.860e+02,
#         1.372e+03, 6.860e+02, 4.660e+02, 3.560e+02])}

# %%
map_img = ttp_generator.putRoutesOnMap([0, 1, 2])
image_show_wait(map_img)
# Out:
# Key 32

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Optimize TTP

# %%
GeneticAlgorithm().help()
# Out:
# chromozome_configs {}
# 'nume': numele obiectului
# 'extern_commnad_file': numele fisierului in care vor fi adaugate comenzile externe, (oprire fortata = stop=True)
# 'genoms': Genoms: "chromosome_name1": (min_range, max_range), "chromosome_name2": (min_range, max_range), ...
# 'metric': Metrics:
#     metoda: 'TTP_linear'; config: -> "v_min":0.1, "v_max":1, "W":2000, "alpha":0.01;
#     metoda: 'TTP_mean_linear'; config: -> "v_min":0.1, "v_max":1, "W":2000, "alpha":0.01;
#     metoda: 'TTP_exp';    config: -> "v_min":0.1, "v_max":1, "W":2000, "lam":0.01;
#     metoda: 'TSP';        config: None;
# 'init_population': InitPopulation:
#     metoda: 'TTP_vecin'; config: -> "lambda_time":0.1, "vmax":1.0, "vmin":0.1, "Wmax":25936, "seed":None;
#     metoda: 'TTP_rand';  config: None;
#     metoda: 'TSP_rand';  config: None;
# 'fitness': Fitness:
#     metoda: 'TSP_f1score'; config: None;
#     metoda: 'TSP_norm';    config: None;
#     metoda: 'TTP_f1score'; config: -> "R":1, ;
#     metoda: 'TTP';         config: -> "R":1, ;
# 'select_parent': {'select_parent1': 'select_parent2'}: SelectParent:
#     metoda: 'choice';      config: None;
#     metoda: 'wheel';       config: None;
#     metoda: 'tour';        config: -> "size_subset":7;
#     metoda: 'tour_choice'; config: -> "size_subset":7;
#     metoda: 'rise';        config: None;
#     metoda: 'mixt';        config: -> "p_select":[1/4, 1/4, 1/4, 1/4], "size_subset":7;
# 'crossover': Crossover:
#     metoda: 'diff';     config None;
#     metoda: 'split';    config None;
#     metoda: 'perm_sim'; config None;
#     metoda: 'mixt';     config -> "p_method":[4/10, 3/10, 3/10], ;
# 'mutate': Mutate:
#     metoda: 'inversion'; config: -> "subset_size":7;
#     metoda: 'scramble';  config: -> "subset_size":7;
#     metoda: 'swap';      config: None;
#     metoda: 'roll';      config: None;
#     metoda: 'insertion'; config: None;
#     metoda: 'rool_sim';  config: None;
#     metoda: 'perm_sim';  config: None;
#     metoda: 'flip_sim';  config: None;
#     metoda: 'mixt';      config: -> "p_method":[4/10, 1/10, 1/10, 3/10, 1/10], "subset_size":7;
# 'callback': Callback:
#     'filename'
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/genoms.py:17: UserWarning: Lipseste numele chromozomilor '{}'
#   warnings.warn("Lipseste numele chromozomilor '{}'".format(gene_range))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:142: UserWarning: Lipseste metoda, pentru functia de 'metric'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:142: UserWarning: Lipseste metoda, pentru functia de 'init_population'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:142: UserWarning: Lipseste metoda, pentru functia de 'fitness'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:142: UserWarning: Lipseste metoda, pentru functia de 'select_parent1'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:142: UserWarning: Lipseste metoda, pentru functia de 'select_parent2'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/callback.py:27: UserWarning: Callback: Numele fisierului 'None' este type '<class 'NoneType'>'
#   warnings.warn("Callback: Numele fisierului '{}' este type '{}'".format(self.filename, type(self.filename)))

# %%
filename_logs = "{}/logs/history.csv".format(LCL_PATH)
extern_commnad_file ="{}/extern_command.cmd".format(LCL_PATH)
ttp = GeneticAlgorithm(
    name="test",
    extern_commnad_file=extern_commnad_file,
    genoms={"tsp":(0, dataset["GENOME_LENGTH"]), "kp":(0, 2)},
    init_population={"method":"TTP_rand", },
    metric={"method":"TTP_linear", "v_min":0.1, "v_max":1, "W":25936, "alpha":0.01},
    fitness={"method":"TTP_f1score", "R":1},
    select_parent1={"method":"tour", "size_subset":7}, 
    select_parent2={"method":"tour_choice", "size_subset":7},
    crossover_tsp={"method":"mixt", "p_method":[4/10, 3/10, 3/10]},
    crossover_kp ={"method":"mixt", "p_method":[4/10, 3/10, 3/10]},
    mutate_tsp={"method":"mixt", "p_method":[4/10, 1/10, 1/10, 3/10, 1/10], "subset_size":7},
    mutate_kp ={"method":"mixt", "p_method":[4/10, 1/10, 1/10, 3/10, 1/10], "subset_size":7},
    callback={"filename":filename_logs, "freq":10}
                      )
ttp.setDataset(dataset)
ttp.setParameters(
    GENOME_LENGTH=dataset["GENOME_LENGTH"], # numarul de alele
    )
print(ttp)
# Out:
# chromozome_configs {'tsp': {'method': 'mixt', 'p_method': [0.4, 0.3, 0.3]}, 'kp': {'method': 'mixt', 'p_method': [0.4, 0.3, 0.3]}}
# Utilizezi metoda: TTP_linear, datele de antrenare trebuie sa corespunda metodei de calcul a metricilor!!!
# Name: test
#
#     GENERATIONS     = 500
#     POPULATION_SIZE = 100
#     GENOME_LENGTH   = 280
#     MUTATION_RATE   = 0.01
#     CROSSOVER_RATE  = 0.5
#     SELECT_RATE     = 0.8
#     ELITE_SIZE      = 5
# Configs:
# Genoms:
# 	Chromozom name: 'tsp': range from (0 to 280)	Chromozom name: 'kp': range from (0 to 2)
# Metrics:
#         method:  TTP_linear
#         configs: {'v_min': 0.1, 'v_max': 1, 'W': 25936, 'alpha': 0.01}
# InitPopulation:
#         method:  TTP_rand
#         configs: {}
# Fitness:
#         method:  TTP_f1score
#         configs: {'R': 1}
# SelectParent:
#         method:  tour
#         configs: {'size_subset': 7}
# SelectParent:
#         method:  tour_choice
#         configs: {'size_subset': 7}
# Crossover:
# 	Chromozome name: 'tsp', method 'mixt', configs: '{'p_method': [0.4, 0.3, 0.3]}'
# 	Chromozome name: 'kp', method 'mixt', configs: '{'p_method': [0.4, 0.3, 0.3]}'
#
# Mutate:
# 	Chromozome name: 'tsp', method 'mixt', configs: '{'p_method': [0.4, 0.1, 0.1, 0.3, 0.1], 'subset_size': 7}'
# 	Chromozome name: 'kp', method 'mixt', configs: '{'p_method': [0.4, 0.1, 0.1, 0.3, 0.1], 'subset_size': 7}'
#
# Callback: filename /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP/logs/history.csv

# %%
ttp.setParameters(
    GENERATIONS     = 5000, # numarul de generatii
    POPULATION_SIZE = 1000, # numarul populatiei
    MUTATION_RATE   = 0.05,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.99,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.99,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 50,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
routes = ttp()
# Out:
# population (1000, 2, (280, 280))
# profits 0.0, weights 108511.0, times 0.8263592720031738,
# profits 0.0, weights 92617.0, times 0.8078378438949585,
# Name:test, Generatia: 0, score: 120681.0, distance: 33022.0, weight: 99281.0, best_fitness: 0.4709812104701996,
# profits 0.0, weights 88815.0, times 0.7735612392425537,
# Name:test, Generatia: 1, score: 115948.0, distance: 33312.0, weight: 95048.0, best_fitness: 0.46979907155036926,
# profits 0.0, weights 78508.0, times 0.7718054056167603,
# Name:test, Generatia: 2, score: 101377.0, distance: 33312.0, weight: 82177.0, best_fitness: 0.4816972613334656,
# profits 0.0, weights 74196.0, times 0.7685858011245728,
# Name:test, Generatia: 3, score: 102457.0, distance: 32152.0, weight: 83057.0, best_fitness: 0.47762829065322876,
# profits 0.0, weights 70742.0, times 0.7542915344238281,
# Name:test, Generatia: 4, score: 102457.0, distance: 32152.0, weight: 83057.0, best_fitness: 0.4649603068828583,
# profits 0.0, weights 2899.0, times 0.8518838286399841,
# Name:test, Generatia: 78, score: 5138.0, distance: 29558.0, weight: 3838.0, best_fitness: 0.48757311701774597,
# profits 0.0, weights 1614.0, times 0.8587898015975952,
# Name:test, Generatia: 79, score: 3922.0, distance: 29558.0, weight: 3022.0, best_fitness: 0.4891608953475952,
# profits 0.0, weights 1475.0, times 0.854464054107666,
# Name:test, Generatia: 80, score: 3922.0, distance: 29558.0, weight: 3022.0, best_fitness: 0.4876224994659424,
# profits 0.0, weights 1391.0, times 0.8542949557304382,
# Name:test, Generatia: 81, score: 2322.0, distance: 29558.0, weight: 1922.0, best_fitness: 0.4895237684249878,
# profits 0.0, weights 742.0, times 0.8554946184158325,
# Name:test, Generatia: 82, score: 2974.0, distance: 29558.0, weight: 2174.0, best_fitness: 0.49338412284851074,
# profits 0.0, weights 686.0, times 0.8507908582687378,
# Name:test, Generatia: 83, score: 2873.0, distance: 29299.0, weight: 2173.0, best_fitness: 0.49315282702445984,
# profits 0.0, weights 56.0, times 0.8450636267662048,
# Name:test, Generatia: 84, score: 2873.0, distance: 28940.0, weight: 2173.0, best_fitness: 0.4931495785713196,
# profits 0.0, weights 150.0, times 0.8554887175559998,
# Name:test, Generatia: 85, score: 2873.0, distance: 28940.0, weight: 2173.0, best_fitness: 0.49366044998168945,
# profits 0.0, weights 150.0, times 0.8603515028953552,
# Name:test, Generatia: 86, score: 2873.0, distance: 28940.0, weight: 2173.0, best_fitness: 0.49382489919662476,
# profits 0.0, weights 56.0, times 0.8677430748939514,
# Name:test, Generatia: 87, score: 2873.0, distance: 28940.0, weight: 2173.0, best_fitness: 0.49226629734039307,
# profits 0.0, weights 56.0, times 0.8831984400749207,
# evolution_scores {'score': np.float64(2873.0), 'distance': np.float64(28949.0), 'weight': np.float64(2173.0), 'best_fitness': np.float32(0.488647)}
# Name:test, Generatia: 88, score: 2873.0, distance: 28949.0, weight: 2173.0, best_fitness: 0.4886470139026642,

# %%
map_img = ttp_generator.putRoutesOnMap(routes["tsp"])
image_show_wait(map_img)
# Out:
# Key 32

# %%
test_dict = {"apa":0, "aparat":1, "apicultor":2, "acustic":3}
test_dict.get("apa", None)

# %%
for key in test_dict.keys():
    idx = key.find("ap")
    if (idx >= 0):
        print(key)

# %% [markdown]
# ## Fit

# %%
#tsp = TSP()
lst_tsp = [TSP("TSP_{}".format(i)) for i in range(6)]
group_tsp = GroupTSP(lst_tsp)

# %%
group_tsp.setParameters(
    POPULATION_SIZE = 300,  # numarul populatiei
    MUTATION_RATE   = 0.085,   # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.3,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    K_DISTANCE      = 1.0,   # coeficientul de inhibare a distantei
    K_NBR_CITY      = 0.9,   # coeficientul de inhibare a numarului de orase
    GENERATIONS     = 10,   # numarul de generatii
    K_BEST          = 25,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
#population = None
#routes, population = tsp(map_of_distance, population)
routes = group_tsp(map_of_distance)

# %%
map_img = ttp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)

# %%
data = np.array([3, 4, 6, 2])

# %%
np.std(data)
