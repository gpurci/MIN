# %% [markdown]
# Travelling salesman problem
# The travelling salesman problem is one of the classic NPhard optimization problems. In this problem, there are n cities
# and the distances between the cities are given by a distance
# matrix D={dij} (dij the distance between city i and j). There is
# a salesman who must visit each city exactly once and
# minimize the time of the complete tour. It is assumed that the
# speed of the salesman is constant (vc) and he tries to minimize
# the time of the tour**3.
# The objective function is given by:
# f(x)=k=1∑n−1​txk​,xk+1​​+txn​,x1​​.

# %%
import numpy as np
from pathlib import Path
import sys

# %%
LCL_PATH  = str(Path().cwd())
SHOW_PATH = str(Path(LCL_PATH).parent.parent)
PARENT_PATH = str(Path(LCL_PATH).parent/"GeneticAlgoritmMethods/my_code")
print("local path:\t{}\nshow path:\t{}\nparent_path:\t{}".format(LCL_PATH, SHOW_PATH, PARENT_PATH))
# Out:
# local path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP
# show path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura
# parent_path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append(PARENT_PATH)
sys.path.append(SHOW_PATH)

def remove_modules(modules_name, *arg):
    if (modules_name in sys.modules):
        del sys.modules[modules_name]
        for key in arg:
            tmp_modules = "{}.{}".format(modules_name, key)
            del sys.modules[tmp_modules]

# %%
remove_modules("imshow")
remove_modules("algoritm_genetic")
remove_modules("builds.ttp_generator")

from imshow import *
from algoritm_genetic import *
from builds.ttp_generator import *

# %% [markdown]
# # Map Generator

# %%
ttp_generator = TTPGenerator("{}/data".format(LCL_PATH))
dataset = ttp_generator(nodes_file="NODE_COORD_SECTION.csv",
                        items_file="ITEMS_SECTION.csv")
dataset
# Out:
# {'GENOME_LENGTH': 280,
#  'distance': array([[ 0., 20., 24., ..., 43., 34., 18.],
#         [20.,  0., 18., ..., 36., 28.,  9.],
#         [24., 18.,  0., ..., 20., 11., 10.],
#         ...,
#         [43., 36., 20., ...,  0.,  9., 29.],
#         [34., 28., 11., ...,  9.,  0., 20.],
#         [18.,  9., 10., ..., 29., 20.,  0.]], shape=(280, 280)),
#  'coords': array([[288, 149],
#         [288, 129],
#         [270, 133],
#         [256, 141],
#         [256, 157],
#         [246, 157],
#         [236, 169],
#         [228, 169],
#         [228, 161],
#         [220, 169],
#         [212, 169],
#         [204, 169],
#         [196, 169],
#         [188, 169],
#         [196, 161],
#         [188, 145],
#         [172, 145],
#         [164, 145],
#         [156, 145],
#         [148, 145],
#         [140, 145],
#         [148, 169],
#         [164, 169],
#         [172, 169],
#         [156, 169],
#         [140, 169],
#         [132, 169],
#         [124, 169],
#         [116, 161],
#         [104, 153],
#         [104, 161],
#         [104, 169],
#         [ 90, 165],
#         [ 80, 157],
#         [ 64, 157],
#         [ 64, 165],
#         [ 56, 169],
#         [ 56, 161],
#         [ 56, 153],
#         [ 56, 145],
#         [ 56, 137],
#         [ 56, 129],
#         [ 56, 121],
#         [ 40, 121],
#         [ 40, 129],
#         [ 40, 137],
#         [ 40, 145],
#         [ 40, 153],
#         [ 40, 161],
#         [ 40, 169],
#         [ 32, 169],
#         [ 32, 161],
#         [ 32, 153],
#         [ 32, 145],
#         [ 32, 137],
#         [ 32, 129],
#         [ 32, 121],
#         [ 32, 113],
#         [ 40, 113],
#         [ 56, 113],
#         [ 56, 105],
#         [ 48,  99],
#         [ 40,  99],
#         [ 32,  97],
#         [ 32,  89],
#         [ 24,  89],
#         [ 16,  97],
#         [ 16, 109],
#         [  8, 109],
#         [  8,  97],
#         [  8,  89],
#         [  8,  81],
#         [  8,  73],
#         [  8,  65],
#         [  8,  57],
#         [ 16,  57],
#         [  8,  49],
#         [  8,  41],
#         [ 24,  45],
#         [ 32,  41],
#         [ 32,  49],
#         [ 32,  57],
#         [ 32,  65],
#         [ 32,  73],
#         [ 32,  81],
#         [ 40,  83],
#         [ 40,  73],
#         [ 40,  63],
#         [ 40,  51],
#         [ 44,  43],
#         [ 44,  35],
#         [ 44,  27],
#         [ 32,  25],
#         [ 24,  25],
#         [ 16,  25],
#         [ 16,  17],
#         [ 24,  17],
#         [ 32,  17],
#         [ 44,  11],
#         [ 56,   9],
#         [ 56,  17],
#         [ 56,  25],
#         [ 56,  33],
#         [ 56,  41],
#         [ 64,  41],
#         [ 72,  41],
#         [ 72,  49],
#         [ 56,  49],
#         [ 48,  51],
#         [ 56,  57],
#         [ 56,  65],
#         [ 48,  63],
#         [ 48,  73],
#         [ 56,  73],
#         [ 56,  81],
#         [ 48,  83],
#         [ 56,  89],
#         [ 56,  97],
#         [104,  97],
#         [104, 105],
#         [104, 113],
#         [104, 121],
#         [104, 129],
#         [104, 137],
#         [104, 145],
#         [116, 145],
#         [124, 145],
#         [132, 145],
#         [132, 137],
#         [140, 137],
#         [148, 137],
#         [156, 137],
#         [164, 137],
#         [172, 125],
#         [172, 117],
#         [172, 109],
#         [172, 101],
#         [172,  93],
#         [172,  85],
#         [180,  85],
#         [180,  77],
#         [180,  69],
#         [180,  61],
#         [180,  53],
#         [172,  53],
#         [172,  61],
#         [172,  69],
#         [172,  77],
#         [164,  81],
#         [148,  85],
#         [124,  85],
#         [124,  93],
#         [124, 109],
#         [124, 125],
#         [124, 117],
#         [124, 101],
#         [104,  89],
#         [104,  81],
#         [104,  73],
#         [104,  65],
#         [104,  49],
#         [104,  41],
#         [104,  33],
#         [104,  25],
#         [104,  17],
#         [ 92,   9],
#         [ 80,   9],
#         [ 72,   9],
#         [ 64,  21],
#         [ 72,  25],
#         [ 80,  25],
#         [ 80,  25],
#         [ 80,  41],
#         [ 88,  49],
#         [104,  57],
#         [124,  69],
#         [124,  77],
#         [132,  81],
#         [140,  65],
#         [132,  61],
#         [124,  61],
#         [124,  53],
#         [124,  45],
#         [124,  37],
#         [124,  29],
#         [132,  21],
#         [124,  21],
#         [120,   9],
#         [128,   9],
#         [136,   9],
#         [148,   9],
#         [162,   9],
#         [156,  25],
#         [172,  21],
#         [180,  21],
# # Genetic Algorithm

# %% [markdown]
# ## Optimize TTP

# %%
GeneticAlgorithm().help()
# Out:
# 'nume': numele obiectului
# 'extern_commnad_file': numele fisierului in care vor fi adaugate comenzile externe, (oprire fortata = stop=True)
# 'metric': Metrics:
#     metoda: 'TTP'; config: -> lambda_time, vmax, vmin, Wmax, seed;
#     metoda: 'TSP'; config: None;
# 'init_population': InitPopulation:
#     metoda: 'TTP_vecin';   config: -> lambda_time, vmax, vmin, Wmax, seed;
#     metoda: 'TTP_rand'; config: None;
#     metoda: 'TSP_rand'; config: None;
# 'fitness': Fitness:
#     metoda: 'TSP_f1score'; config: None;
#     metoda: 'TSP_norm';    config: None;
#     metoda: 'TTP_linear';  config: -> v_max, v_min, W, R, alpha;
#     metoda: 'TTP_exp';     config: -> v_max, v_min, W, R, lam;
# 'select_parent': {'select_parent1': 'select_parent2'}: SelectParent:
#     metoda: 'choice';        config: None;
#     metoda: 'roata';         config: None;
#     metoda: 'turneu';        config: -> size_subset;
#     metoda: 'turneu_choice'; config: -> size_subset;
#     metoda: 'crescator';     config: None;
#     metoda: 'mixt';          config: -> p_select[1/4, 1/4, 1/4, 1/4], size_subset;
# 'crossover': Crossover:
#     metoda: 'diff';     config None;
#     metoda: 'split';    config None;
#     metoda: 'perm_sim'; config None;
#     metoda: 'mixt';     config None;
# 'mutate': Mutate:
#     metoda: 'inversion'; config: None;
#     metoda: 'scramble';  config: None;
#     metoda: 'swap';      config: None;
#     metoda: 'roll';      config: None;
#     metoda: 'insertion'; config: None;
#     metoda: 'rool_sim';  config: None;
#     metoda: 'perm_sim';  config: None;
#     metoda: 'flip_sim';  config: None;
#     metoda: 'mixt';      config: -> p_method[4/10, 1/10, 1/10, 3/10, 1/10], size_subset;
# 'callback': Callback:
#     'filename'
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'metric'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'init_population'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'fitness'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'select_parent1'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'select_parent2'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'crossover'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:130: UserWarning: Lipseste metoda, pentru functia de 'mutate'
#   warnings.warn("Lipseste metoda, pentru functia de '{}'".format(str_functia))
# /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/callback.py:27: UserWarning: Callback: Numele fisierului 'None' este type '<class 'NoneType'>'

# %%
filename_logs = "{}/logs/history.csv".format(LCL_PATH)
extern_commnad_file ="{}/extern_command.cmd".format(LCL_PATH)
ttp = GeneticAlgorithm(
    name="test",
    extern_commnad_file=extern_commnad_file,
    metric={"method":"TSP", },
    init_population={"method":"TSP_rand", },
    fitness={"method":"TSP_f1score", },
    select_parent= {"select_parent1":{"method":"turneu", }, "select_parent2":{"method":"turneu_choice", }},
    crossover={"method":"split", },
    mutate={"method":"swap", },
    callback=filename_logs
                      )
ttp.setDataset(dataset)
ttp.setParameters(
    GENOME_LENGTH=dataset["GENOME_LENGTH"], # numarul de alele
    )
print(ttp)
# Out:
# Utilizezi metoda: TSP, datele de antrenare trebuie sa corespunda metodei de calcul a metricilor!!!
# Name: test
#
#     GENERATIONS     = 500
#     POPULATION_SIZE = 100
#     GENOME_LENGTH   = 280
#     MUTATION_RATE   = 0.01
#     CROSSOVER_RATE  = 0.5
#     SELECT_RATE     = 0.8
#     ELITE_SIZE      = 5
# Configs:
# Metrics:
#         method:  TSP
#         configs: {}
# InitPopulation:
#         method:  TSP_rand
#         configs: {}
# Fitness:
#         method:  TSP_f1score
#         configs: {}
# SelectParent:
#         method:  turneu
#         configs: {}
# SelectParent:
#         method:  turneu_choice
#         configs: {}
# Crossover:
#         method:  split
#         configs: {}
# Mutate:
#         method:  swap
#         configs: {}
# Callback: filename /home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP/logs/history.csv

# %%
ttp.setParameters(
    GENERATIONS     = 5000, # numarul de generatii
    POPULATION_SIZE = 1000, # numarul populatiei
    MUTATION_RATE   = 0.05,  # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.99,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.99,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    ELITE_SIZE      = 50,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
#print(tsp)
population = None
routes, population = ttp(population)
# Out:
# population (1000, 280)
# Name:test, Generatia: 0, score: 31331.0, best_fitness: 0.991,
# Name:test, Generatia: 1, score: 31192.0, best_fitness: 0.988,
# Name:test, Generatia: 2, score: 31192.0, best_fitness: 0.989,
# Name:test, Generatia: 3, score: 31048.0, best_fitness: 0.984,
# Name:test, Generatia: 4, score: 31048.0, best_fitness: 0.984,
# Name:test, Generatia: 5, score: 30844.0, best_fitness: 0.984,
# Name:test, Generatia: 6, score: 30652.0, best_fitness: 0.983,
# Name:test, Generatia: 7, score: 30488.0, best_fitness: 0.989,
# Name:test, Generatia: 8, score: 30331.0, best_fitness: 0.99,
# Name:test, Generatia: 9, score: 30331.0, best_fitness: 0.988,
# Name:test, Generatia: 10, score: 30213.0, best_fitness: 0.985,
# Name:test, Generatia: 11, score: 30213.0, best_fitness: 0.985,
# Name:test, Generatia: 12, score: 30182.0, best_fitness: 0.986,
# Name:test, Generatia: 13, score: 30103.0, best_fitness: 0.988,
# Name:test, Generatia: 14, score: 30027.0, best_fitness: 0.992,
# Name:test, Generatia: 15, score: 29755.0, best_fitness: 0.995,
# Name:test, Generatia: 16, score: 29556.0, best_fitness: 0.993,
# Name:test, Generatia: 17, score: 29556.0, best_fitness: 0.993,
# Name:test, Generatia: 18, score: 29399.0, best_fitness: 0.995,
# Name:test, Generatia: 19, score: 29275.0, best_fitness: 0.995,
# Name:test, Generatia: 20, score: 29180.0, best_fitness: 0.996,
# Name:test, Generatia: 21, score: 29023.0, best_fitness: 0.997,
# Name:test, Generatia: 22, score: 29017.0, best_fitness: 0.997,
# Name:test, Generatia: 23, score: 28978.0, best_fitness: 0.996,

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 11
#       9 #print(tsp)
#      10 population = None
# ---> 11 routes, population = ttp(population)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/algoritm_genetic.py:99, in GeneticAlgorithm.__call__(self, population)
#      97 population = np.array(new_population)
#      98 # calculate metrics
# ---> 99 metric_values  = self.metrics(population)
#     100 # calculare fitness
#     101 fitness_values = self.fitness(population, metric_values)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/metrics.py:26, in Metrics.__call__(self, population)
#      25 def __call__(self, population):
# ---> 26     return self.fn(population, **self.__configs)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/metrics.py:114, in Metrics.metricsTSP(self, population)
#     109 """ Returneaza o valoare normalizata, formula 2*weights*profits/(weights+profits)
#     110 unde: valoarea distantei este invers normalizata, iar valoarea numarului de orase direct normalizata
#     111 population - populatia, vector de indivizi
#     112 """
#     113 # calculeaza distanta
# --> 114 distances   = self.__getDistances(population)
#     115 # calculeaza numarul de orase unice
#     116 number_city = self.__getNumberCities(population)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/metrics.py:98, in Metrics.__getDistances(self, population)
#      96 def __getDistances(self, population):
#      97     """Calculaza distanta pentru fiecare individ din populatiei"""
# ---> 98     return np.apply_along_axis(self.__getIndividDistance,
#      99                                     axis=1,
#     100                                     arr=population)
#
# File ~/venvs/torch_env/lib/python3.12/site-packages/numpy/lib/_shape_base_impl.py:409, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     407 buff[ind0] = res
#     408 for ind in inds:
# --> 409     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     411 res = transpose(buff, buff_permute)
#     412 return conv.wrap(res)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/GeneticAlgoritmMethods/my_code/metrics.py:90, in Metrics.__getIndividDistance(self, individ)
#      88 """Calculul distantei pentru un individ"""
#      89 distances = self.dataset["distance"][individ[:-1], individ[1:]]
# ---> 90 distance  = distances.sum() + self.dataset["distance"][individ[-1], individ[0]]
#      91 return distance
#
# File ~/venvs/torch_env/lib/python3.12/site-packages/numpy/_core/_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
map_img = ttp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)
# Out:
# Key 32

# %% [markdown]
# ## Fit

# %%
#tsp = TSP()
lst_tsp = [TSP("TSP_{}".format(i)) for i in range(6)]
group_tsp = GroupTSP(lst_tsp)

# %%
group_tsp.setParameters(
    POPULATION_SIZE = 300,  # numarul populatiei
    MUTATION_RATE   = 0.085,   # threshold-ul pentru a face o mutatie genetica
    CROSSOVER_RATE  = 0.5,   # threshold-ul pentru incrucisarea parintilor
    SELECT_RATE     = 0.3,   # threshold-ul de selectie, selectare dupa compatibilitate sau dupa probabilitate
    K_DISTANCE      = 1.0,   # coeficientul de inhibare a distantei
    K_NBR_CITY      = 0.9,   # coeficientul de inhibare a numarului de orase
    GENERATIONS     = 10,   # numarul de generatii
    K_BEST          = 25,     # salveaza pentru urmatoarea generatie numarul de indivizi, cu cel mai mare scor
    )
#population = None
#routes, population = tsp(map_of_distance, population)
routes = group_tsp(map_of_distance)

# %%
map_img = ttp_generator.putRoutesOnMap(routes)
image_show_wait(map_img)

# %%
data = np.array([3, 4, 6, 2])

# %%
np.std(data)
