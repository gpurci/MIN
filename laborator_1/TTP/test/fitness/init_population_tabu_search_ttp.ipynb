# %% [markdown]
# Test manager of root functionality

# %%
import sys
from pathlib import Path
import seaborn as sns

# %%
LCL_PATH  = str(Path().cwd().parent.parent)
ROOT_PATH = str(Path(LCL_PATH).parent.parent)
EXTERN_CMD_PATH = str(Path(ROOT_PATH))
GENERIC_PATH    = str(Path(ROOT_PATH)/"GeneticAlgorithmManager")
SPECIFIC_PATH   = str(Path(ROOT_PATH)/"extension")
print("""
root path:\t{}
local path:\t{}
generic_path:\t{}
project_specific_path:\t{}
extern_cmd_path: \t{}""".format(ROOT_PATH, LCL_PATH, GENERIC_PATH, SPECIFIC_PATH, EXTERN_CMD_PATH))
# Out:
# root path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura
# local path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP
# generic_path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/GeneticAlgorithmManager
# project_specific_path:	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/extension
# extern_cmd_path: 	/home/gheorghe/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura

# %%
# adding local_folder to the system path
sys.path.append(LCL_PATH)
sys.path.append(ROOT_PATH)
sys.path.append(GENERIC_PATH)
sys.path.append(SPECIFIC_PATH)

from sys_function import * # este in root

# %%
sys_remove_modules("imshow")
sys_remove_modules("algoritm_genetic") # facem update doar daca modificam ceva in generic
sys_remove_modules("genoms") # 
sys_remove_modules("builds.init_population.init_population_tabu_search_ttp")
sys_remove_modules("builds.dataset_utils.dataset_ttp_man")
sys_remove_modules("builds.dataset_utils.ttp_generator")

from imshow import *
from algoritm_genetic import *
from genoms import *
from builds.init_population.init_population_tabu_search_ttp import *
from builds.dataset_utils.dataset_ttp_man import *
from builds.dataset_utils.ttp_generator import *

# %% [markdown]
# # Data aquisition

# %%
ttp_generator = TTPGenerator("{}/data".format(LCL_PATH))
dataset = ttp_generator(nodes_file="NODE_COORD_SECTION.csv",
                        items_file="ITEMS_SECTION.csv")
dataset
# Out:
# {'GENOME_LENGTH': 280,
#  'distance': array([[ 0., 20., 24., ..., 43., 34., 18.],
#         [20.,  0., 18., ..., 36., 28.,  9.],
#         [24., 18.,  0., ..., 20., 11., 10.],
#         ...,
#         [43., 36., 20., ...,  0.,  9., 29.],
#         [34., 28., 11., ...,  9.,  0., 20.],
#         [18.,  9., 10., ..., 29., 20.,  0.]], shape=(280, 280)),
#  'coords': array([[288, 149],
#         [288, 129],
#         [270, 133],
#         [256, 141],
#         [256, 157],
#         [246, 157],
#         [236, 169],
#         [228, 169],
#         [228, 161],
#         [220, 169],
#         [212, 169],
#         [204, 169],
#         [196, 169],
#         [188, 169],
#         [196, 161],
#         [188, 145],
#         [172, 145],
#         [164, 145],
#         [156, 145],
#         [148, 145],
#         [140, 145],
#         [148, 169],
#         [164, 169],
#         [172, 169],
#         [156, 169],
#         [140, 169],
#         [132, 169],
#         [124, 169],
#         [116, 161],
#         [104, 153],
#         [104, 161],
#         [104, 169],
#         [ 90, 165],
#         [ 80, 157],
#         [ 64, 157],
#         [ 64, 165],
#         [ 56, 169],
#         [ 56, 161],
#         [ 56, 153],
#         [ 56, 145],
#         [ 56, 137],
#         [ 56, 129],
#         [ 56, 121],
#         [ 40, 121],
#         [ 40, 129],
#         [ 40, 137],
#         [ 40, 145],
#         [ 40, 153],
#         [ 40, 161],
#         [ 40, 169],
#         [ 32, 169],
#         [ 32, 161],
#         [ 32, 153],
#         [ 32, 145],
#         [ 32, 137],
#         [ 32, 129],
#         [ 32, 121],
#         [ 32, 113],
#         [ 40, 113],
#         [ 56, 113],
#         [ 56, 105],
#         [ 48,  99],
#         [ 40,  99],
#         [ 32,  97],
#         [ 32,  89],
#         [ 24,  89],
#         [ 16,  97],
#         [ 16, 109],
#         [  8, 109],
#         [  8,  97],
#         [  8,  89],
#         [  8,  81],
#         [  8,  73],
#         [  8,  65],
#         [  8,  57],
#         [ 16,  57],
#         [  8,  49],
#         [  8,  41],
#         [ 24,  45],
#         [ 32,  41],
#         [ 32,  49],
#         [ 32,  57],
#         [ 32,  65],
#         [ 32,  73],
#         [ 32,  81],
#         [ 40,  83],
#         [ 40,  73],
#         [ 40,  63],
#         [ 40,  51],
#         [ 44,  43],
#         [ 44,  35],
#         [ 44,  27],
#         [ 32,  25],
#         [ 24,  25],
#         [ 16,  25],
#         [ 16,  17],
#         [ 24,  17],
#         [ 32,  17],
#         [ 44,  11],
#         [ 56,   9],
#         [ 56,  17],
#         [ 56,  25],
#         [ 56,  33],
#         [ 56,  41],
#         [ 64,  41],
#         [ 72,  41],
#         [ 72,  49],
#         [ 56,  49],
#         [ 48,  51],
#         [ 56,  57],
#         [ 56,  65],
#         [ 48,  63],
#         [ 48,  73],
#         [ 56,  73],
#         [ 56,  81],
#         [ 48,  83],
#         [ 56,  89],
#         [ 56,  97],
#         [104,  97],
#         [104, 105],
#         [104, 113],
#         [104, 121],
#         [104, 129],
#         [104, 137],
#         [104, 145],
#         [116, 145],
#         [124, 145],
#         [132, 145],
#         [132, 137],
#         [140, 137],
#         [148, 137],
#         [156, 137],
#         [164, 137],
#         [172, 125],
#         [172, 117],
#         [172, 109],
#         [172, 101],
#         [172,  93],
#         [172,  85],
#         [180,  85],
#         [180,  77],
#         [180,  69],
#         [180,  61],
#         [180,  53],
#         [172,  53],
#         [172,  61],
#         [172,  69],
#         [172,  77],
#         [164,  81],
#         [148,  85],
#         [124,  85],
#         [124,  93],
#         [124, 109],
#         [124, 125],
#         [124, 117],
#         [124, 101],
#         [104,  89],
#         [104,  81],
#         [104,  73],
#         [104,  65],
#         [104,  49],
#         [104,  41],
#         [104,  33],
#         [104,  25],
#         [104,  17],
#         [ 92,   9],
#         [ 80,   9],
#         [ 72,   9],
#         [ 64,  21],
#         [ 72,  25],
#         [ 80,  25],
#         [ 80,  25],
#         [ 80,  41],
#         [ 88,  49],
#         [104,  57],
#         [124,  69],
#         [124,  77],
#         [132,  81],
#         [140,  65],
#         [132,  61],
#         [124,  61],
#         [124,  53],
#         [124,  45],
#         [124,  37],
#         [124,  29],
#         [132,  21],
#         [124,  21],
#         [120,   9],
#         [128,   9],
#         [136,   9],
#         [148,   9],
#         [162,   9],
#         [156,  25],
#         [172,  21],
#         [180,  21],
#         [180,  29],
#         [172,  29],
#         [172,  37],
#         [172,  45],
#         [180,  45],
#         [180,  37],
#         [188,  41],
#         [196,  49],
#         [204,  57],
#         [212,  65],
#         [220,  73],
#         [228,  69],
#         [228,  77],
#         [236,  77],
#         [236,  69],
#         [236,  61],
#         [228,  61],
#         [228,  53],
#         [236,  53],
#         [236,  45],
#         [228,  45],
#         [228,  37],
#         [236,  37],
#         [236,  29],
#         [228,  29],
#         [228,  21],
#         [236,  21],
#         [252,  21],
#         [260,  29],
#         [260,  37],
#         [260,  45],
#         [260,  53],
#         [260,  61],
#         [260,  69],
#         [260,  77],
#         [276,  77],
#         [276,  69],
#         [276,  61],
#         [276,  53],
#         [284,  53],
#         [284,  61],
#         [284,  69],
#         [284,  77],
#         [284,  85],
#         [284,  93],
#         [284, 101],
#         [288, 109],
#         [280, 109],
#         [276, 101],
#         [276,  93],
#         [276,  85],
#         [268,  97],
#         [260, 109],
#         [252, 101],
#         [260,  93],
#         [260,  85],
#         [236,  85],
#         [228,  85],
#         [228,  93],
#         [236,  93],
#         [236, 101],
#         [228, 101],
#         [228, 109],
#         [228, 117],
#         [228, 125],
#         [220, 125],
#         [212, 117],
#         [204, 109],
#         [196, 101],
#         [188,  93],
#         [180,  93],
#         [180, 101],
#         [180, 109],
#         [180, 117],
#         [180, 125],
#         [196, 145],
#         [204, 145],
#         [212, 145],
#         [220, 145],
#         [228, 145],
#         [236, 145],
#         [246, 141],
#         [252, 125],
#         [260, 129],
#         [280, 133]], dtype=int32),
#  'item_profit': array([   0,  101,  202,  404,  202,  996, 1992, 3984,  467,  934, 1868,
#          790,  790,  713, 1426, 2852,  974,  974,  222,  444,  888,  666,
#          586, 1172, 1172,  923,  923,  563, 1126,  563,  689, 1378, 1378,
#          425,  850, 1700, 1275, 1100, 2200, 4400,  876, 1752, 2628,  223,
#          456,  405,  810, 1620,  405,  147,  294,  588,  745, 1490, 2980,
#         1490,  239,  347,  694, 1388, 1041,  311,  622, 1244,  933,  200,
#          400,  800,  200,  727, 1454, 1454,  860, 1720,  876, 1752, 3504,
#          575, 1150, 2300, 1037, 2074, 4148, 1037,  201,  402,  804,  402,
#          381,  762, 1524,  762,  851, 1702, 3404, 1702,  630, 1260, 2520,
#          340,  680,  680,  348,  696, 1044,  868,  131,  262,  131,  713,
#         1426, 2852,  713,  981, 1962, 1962,  467,  934, 1868,  467,  812,
#          510, 1020, 2040,  510,  257,  514, 1028,  771,  924,  342,  572,
#         1144, 1716,  822, 1644, 3288,  875,  875,  471,  942, 1884,  437,
#          874,  437,  985, 1970, 3940, 1970,  304,  608, 1216,  608,  694,
#         1388, 2776, 1388,  326,  652, 1304,  326,  652, 1021,  637, 1274,
#         2548,  212,  212, 1059, 2118, 3177,  492,  492,  809, 1618, 3236,
#         1040, 2080, 1043, 2086, 4172,  179,  179, 1022, 2044, 2044,  461,
#         1047, 2094, 1047,  961, 1922, 3844, 2883, 1037, 2074, 4148, 3111,
#          854, 1708, 2562,  972,  736,  736,  559, 1118, 2236, 1677,  490,
#          490,  241,  482,  723,  211,  422,  844,  633,  688, 1376,  688,
#          106,  106,  255,  510, 1020,  765,  823, 1646, 3292, 1646,  823,
#         1646, 3292, 2469,  767, 1534, 1534,  929, 1858, 3716,  929,  587,
#         1174, 1174,  690, 1380, 2760, 1380,  470,  940, 1880,  923, 1846,
#         3692,  923,  273,  546,  156, 1077, 2154, 3231,  781, 1562, 2343,
#          789, 1578, 3156,  789, 1033, 2066, 3099,  909, 1818,  687, 1374,
#          786, 1572,  786,  566,  456]),
#  'item_weight': array([   0,    1,    2,    4,    2,  896, 1792, 3584,  367,  734, 1468,
#          690,  690,  613, 1226, 2452,  874,  874,  122,  244,  488,  366,
#          486,  972,  972,  823,  823,  463,  926,  463,  589, 1178, 1178,
#          325,  650, 1300,  975, 1000, 2000, 4000,  776, 1552, 2328,  123,
#          356,  305,  610, 1220,  305,   47,   94,  188,  645, 1290, 2580,
#         1290,  139,  247,  494,  988,  741,  211,  422,  844,  633,  100,
#          200,  400,  100,  627, 1254, 1254,  760, 1520,  776, 1552, 3104,
#          475,  950, 1900,  937, 1874, 3748,  937,  101,  202,  404,  202,
#          281,  562, 1124,  562,  751, 1502, 3004, 1502,  530, 1060, 2120,
#          240,  480,  480,  248,  496,  744,  768,   31,   62,   31,  613,
#         1226, 2452,  613,  881, 1762, 1762,  367,  734, 1468,  367,  712,
#          410,  820, 1640,  410,  157,  314,  628,  471,  824,  242,  472,
#          944, 1416,  722, 1444, 2888,  775,  775,  371,  742, 1484,  337,
#          674,  337,  885, 1770, 3540, 1770,  204,  408,  816,  408,  594,
#         1188, 2376, 1188,  226,  452,  904,  226,  452,  921,  537, 1074,
#         2148,  112,  112,  959, 1918, 2877,  392,  392,  709, 1418, 2836,
#          940, 1880,  943, 1886, 3772,   79,   79,  922, 1844, 1844,  361,
#          947, 1894,  947,  861, 1722, 3444, 2583,  937, 1874, 3748, 2811,
#          754, 1508, 2262,  872,  636,  636,  459,  918, 1836, 1377,  390,
#          390,  141,  282,  423,  111,  222,  444,  333,  588, 1176,  588,
#            6,    6,  155,  310,  620,  465,  723, 1446, 2892, 1446,  723,
#         1446, 2892, 2169,  667, 1334, 1334,  829, 1658, 3316,  829,  487,
#          974,  974,  590, 1180, 2360, 1180,  370,  740, 1480,  823, 1646,
#         3292,  823,  173,  346,   56,  977, 1954, 2931,  681, 1362, 2043,
#          689, 1378, 2756,  689,  933, 1866, 2799,  809, 1618,  587, 1174,
#          686, 1372,  686,  466,  356])}

# %%
dataset_obj = DatasetTTPMan(dataset)

# %% [markdown]
# # InitPopulationTabuSearch

# %%
obj = InitPopulationTabuSearch("init", dataset_man=dataset_obj, city=0, window_size=4, v_min=0.1, v_max=1, W=25936, R=5.61)
obj.setParameters(GENOME_LENGTH=dataset["GENOME_LENGTH"])

# %% [markdown]
# ## __call__

# %%
genoms = obj(1)

# %%
for elite_pos in np.arange(2):
    print(elite_pos)
    tsp_individ = genoms["tsp"][elite_pos]
    kp_individ  = genoms["kp"][elite_pos]
    score = dataset_obj.computeIndividScore(tsp_individ, kp_individ, v_min=0.1, v_max=1, W=25936, R=5.61)
    profit = dataset_obj.computeIndividProfit(kp_individ)
    weight = dataset_obj.computeIndividWeight(kp_individ)
    print("score {}, weight {}, profit {}".format(score, weight, profit))
    map_imgp = ttp_generator.putRoutesOnMap(tsp_individ)
    image_show_wait(map_imgp, window_name="Parent")

# %% [markdown]
# ## computeRoute

# %% [markdown]
# ## computeProfit

# %%
for idx in range(10):
    tmp_profit = obj.computeProfit(1, [ret_route], v_min=0.1, v_max=1, W=25936, R=5.61)
    score  = dataset_obj.computeIndividScore(ret_route, tmp_profit[0], v_min=0.1, v_max=1, W=25936, R=5.61)
    profit = dataset_obj.computeIndividProfit(tmp_profit)
    weight = dataset_obj.computeIndividWeight(tmp_profit)
    print("score {}, weight {}, profit {}".format( score, weight, profit))
# Out:
# score 10473.892973253594, weight 24275, profit 34175
# score 10187.549148333917, weight 24625, profit 33025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 for idx in range(10):
# ----> 2     tmp_profit = obj.computeProfit(1, [ret_route], v_min=0.1, v_max=1, W=25936, R=5.61)
#       3     score  = dataset_obj.computeIndividScore(ret_route, tmp_profit[0], v_min=0.1, v_max=1, W=25936, R=5.61)
#       4     profit = dataset_obj.computeIndividProfit(tmp_profit)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP/builds/init_population/init_population_tabu_search_ttp.py:124, in InitPopulationTabuSearch.computeProfit(self, population_size, tsp_population, v_min, v_max, W, R)
#     122 is_find = True
#     123 while (is_find): # cauta cea mai buna ruta,
# --> 124     profit, is_find = self.tabu_search_score(route, profit, v_min, v_max, W, R)
#     125     tmp_profit = self.erase_weightier_objects(profit, W)
#     126     tmp_score  = self.dataset_man.computeIndividScore(route, tmp_profit, v_min=v_min, v_max=v_max, W=W, R=R)
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP/builds/init_population/init_population_tabu_search_ttp.py:157, in InitPopulationTabuSearch.tabu_search_score(self, tsp_individ, kp_individ, v_min, v_max, W, R)
#     155 tmp[locus1] = 0
#     156 tmp[locus2] = 1
# --> 157 score = self.dataset_man.computeIndividScore(tsp_individ, tmp, v_min=v_min, v_max=v_max, W=W, R=R)
#     158 if (score > best_score):
#     159     best_score   = score
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP/builds/dataset_utils/dataset_ttp_man.py:98, in computeIndividScore(self, tsp_individ, kp_individ, v_min, v_max, W, R)
#      96 # calculeaza viteza pentru cel mai bun individ
#      97 speeds = self.computeIndividSpeeds(tsp_individ, kp_individ, v_min=v_min, v_max=v_max, W=W)
# ---> 98 # calculeaza distanta dintre orase pentru cel mai bun individ
#      99 cities_distances = self.individCityDistance(tsp_individ)
#     100 # calculeaza timpul pentru cel mai bun individ
#
# File ~/Desktop/Proiecte/master/MIN_metode_inspirate_din_natura/laborator_1/TTP/builds/dataset_utils/dataset_ttp_man.py:91, in computeIndividSpeeds(self, tsp_individ, kp_individ, v_min, v_max, W)
#      89     speed     = v_max - (v_max - v_min) * (Wcur / W)
#      90     speeds[i] = max(v_min, speed)
# ---> 91 return speeds
#
# KeyboardInterrupt:

# %%
score  = dataset_obj.computeIndividScore(ret_route, tmp_profit[0], v_min=0.1, v_max=1, W=25936, R=5.61)
profit = dataset_obj.computeIndividProfit(tmp_profit)
weight = dataset_obj.computeIndividWeight(tmp_profit)
print("score {}, weight {}, profit {}".format( score, weight, profit))
# Out:
# score 9007.85663657442, weight 24334, profit 33534

# %% [markdown]
# ## insertion_tabu_search_distance

# %%
route, city = np.arange(280, dtype=np.int32), 0
is_find = True
count = 0
ret_route = route.copy()
while (is_find and (count < 1000)):
    ret_route, is_find = obj.insertion_tabu_search_distance(ret_route, city)
    old_distance = dataset_obj.computeIndividDistance(route)
    new_distance = dataset_obj.computeIndividDistance(ret_route)
    count += 1
print("old distance {}, new distance {}, count {}".format(old_distance, new_distance, count))
map_imgo = ttp_generator.putRoutesOnMap(route)
map_imgp = ttp_generator.putRoutesOnMap(ret_route)
image_show(map_imgo, window_name="Old")
image_show_wait(map_imgp, window_name="Tabu")
# Out:
# old distance 2808.0, new distance 2806.0, count 1000
# Key 32

# %% [markdown]
# ## tabu_search_score

# %%
tmp_profit = np.random.randint(low=0, high=2, size=obj.GENOME_LENGTH)
for idx in range(10):
    tmp_profit, is_find = obj.tabu_search_score(ret_route, tmp_profit, v_min=0.1, v_max=1, W=25936, R=5.61)
    tmp_profit = obj.erase_weightier_objects(tmp_profit, 25936)
    score  = dataset_obj.computeIndividScore(ret_route, tmp_profit, v_min=0.1, v_max=1, W=25936, R=5.61)
    profit = dataset_obj.computeIndividProfit(tmp_profit)
    weight = dataset_obj.computeIndividWeight(tmp_profit)
    print("is_find {}, score {}, weight {}, profit {}".format(is_find, score, weight, profit))
# Out:
# argmax 180
# argmax 82
# argmax 196
# argmax 147
# argmax 192
# argmax 239
# argmax 253
# argmax 76
# argmax 94
# argmax 228
# argmax 232
# argmax 170
# argmax 175
# argmax 266
# argmax 193
# argmax 111
# argmax 246
# argmax 42
# argmax 233
# argmax 263
# argmax 259
# argmax 79
# argmax 177
# argmax 195
# argmax 184
# argmax 185
# argmax 206
# argmax 115
# argmax 238
# argmax 75
# argmax 10
# argmax 118
# argmax 227
# argmax 135
# argmax 174
# argmax 133
# argmax 207
# argmax 276
# argmax 53
# argmax 55
# argmax 71
# argmax 110
# argmax 47
# argmax 156
# argmax 218
# argmax 274
# argmax 90
# argmax 164
# argmax 97
# argmax 37
# argmax 59
# argmax 36
# argmax 242
# argmax 243
# argmax 24
# argmax 78
# argmax 187
# argmax 189
# argmax 132
# argmax 80
# argmax 28
# argmax 183
# argmax 205
# argmax 159
# argmax 113
# argmax 16
# argmax 17
# argmax 201
# argmax 190
# argmax 63
# argmax 254
# argmax 271
# argmax 40
# argmax 74
# argmax 137
# argmax 72
# argmax 198
# argmax 140
# argmax 249
# argmax 9
# argmax 117
# argmax 226
# is_find True, score -4010.636475716412, weight 25345, profit 35445
# argmax 276
# is_find True, score -2020.0096640193733, weight 24633, profit 34633
# is_find True, score 380.69924073336733, weight 25360, profit 35460
# argmax 270
# is_find True, score 1705.1179901866199, weight 24747, profit 34747
# argmax 270
# is_find True, score 2682.3210280512394, weight 24025, profit 33925
# argmax 270
# is_find True, score 3403.4986262595376, weight 23375, profit 33075
# is_find True, score 5436.3058111472565, weight 25561, profit 35461
# argmax 270
# is_find True, score 5885.922094836205, weight 24905, profit 34805
# argmax 270
# is_find True, score 6379.408865971429, weight 24419, profit 34219
# argmax 270
# is_find True, score 6741.313248883678, weight 23956, profit 33656
