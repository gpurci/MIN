# %% [markdown]
# # No multi-repair + stress + VND with KP LS only

# %%
import numpy as np
from pathlib import Path
from builds.ttp_generator import *
import sys

LCL_PATH  = str(Path().cwd())
ROOT_PATH = str(Path(LCL_PATH).parent.parent)
EXTERN_CMD_PATH = str(Path(ROOT_PATH))
GENERIC_PATH    = str(Path(ROOT_PATH) / "GeneticAlgorithmManager/my_code")
SPECIFIC_PATH   = str(Path(ROOT_PATH) / "extension")

print("""
root path:\t{}
local path:\t{}
generic_path:\t{}
project_specific_path:\t{}
extern_cmd_path:\t{}""".format(ROOT_PATH, LCL_PATH, GENERIC_PATH, SPECIFIC_PATH, EXTERN_CMD_PATH))

sys.path.append(ROOT_PATH)
sys.path.append(LCL_PATH)
sys.path.append(GENERIC_PATH)
sys.path.append(SPECIFIC_PATH)

ttp_generator = TTPGenerator("{}/data".format(LCL_PATH))
dataset = ttp_generator(
    nodes_file="NODE_COORD_SECTION.csv",
    items_file="ITEMS_SECTION.csv",
)
# Out:
# root path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN
# local path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\laborator_1\TTP
# generic_path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\GeneticAlgorithmManager\my_code
# project_specific_path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension
# extern_cmd_path:	c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN

# %%
from builder_ttp import (
    build_ttp_ga,
    BASE_DATASET,
    GA_BEST_CANDIDATE,
)

dataset.update(BASE_DATASET)

cfg = GA_BEST_CANDIDATE

extern_command_file = "{}/extern_command.cmd".format(EXTERN_CMD_PATH)
log_file = "{}/logs/{}_history.csv".format(LCL_PATH, cfg["id"])

ttp = build_ttp_ga(dataset, cfg, extern_command_file, log_file)

print("Config ID:", cfg["id"])
print(cfg["description"])
print("GA params:", {k: cfg[k] for k in ["population_size", "generations", "mutation_rate", "crossover_rate"]})

best_individ = ttp()
best_individ
# Out:
# setParameters: {'GENOME_LENGTH': 280, 'GENERATIONS': 150, 'POPULATION_SIZE': 400, 'MUTATION_RATE': 0.08, 'CROSSOVER_RATE': 0.7, 'SELECT_RATE': 0.5, 'W': 25936, 'v_min': 0.1, 'v_max': 1.0, 'R': 5.61, 'ELITE_SIZE': 40, 'ELITE_FREQ': 8}
# Config ID: ga_best_candidate
# No multi-repair, stress ON, VND with KP-LS only
# GA params: {'population_size': 400, 'generations': 150, 'mutation_rate': 0.08, 'crossover_rate': 0.7}
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_best_candidate, Generatia: 0, score: 5078.206, profit: 36379.0, time: 5579.464, distance: 2918.0, weight: 25679.0, best_fitness: 765662.48,
# Name:ga_best_candidate, Generatia: 1, score: 9967.076, profit: 37764.0, time: 4954.888, distance: 2852.0, weight: 25764.0, best_fitness: 450403.703,
# Name:ga_best_candidate, Generatia: 2, score: 6602.076, profit: 35768.0, time: 5198.917, distance: 2844.0, weight: 25868.0, best_fitness: 386775.89,
# Name:ga_best_candidate, Generatia: 3, score: 7989.091, profit: 33649.0, time: 4573.959, distance: 2769.0, weight: 23149.0, best_fitness: 583401.239,
# Name:ga_best_candidate, Generatia: 4, score: 8185.264, profit: 35768.0, time: 4916.709, distance: 2873.0, weight: 25868.0, best_fitness: 397233.0,
# Name:ga_best_candidate, Generatia: 5, score: 8185.264, profit: 35768.0, time: 4916.709, distance: 2873.0, weight: 25868.0, best_fitness: 382449.006,
# Name:ga_best_candidate, Generatia: 6, score: 8841.293, profit: 36647.0, time: 4956.454, distance: 2918.0, weight: 24647.0, best_fitness: 394016.243,
# Name:ga_best_candidate, Generatia: 7, score: 11031.358, profit: 36579.0, time: 4553.947, distance: 2798.0, weight: 24079.0, best_fitness: 293125.679,
# Name:ga_best_candidate, Generatia: 8, score: 11188.31, profit: 37693.0, time: 4724.544, distance: 2798.0, weight: 24193.0, best_fitness: 363187.016,
# Name:ga_best_candidate, Generatia: 9, score: 11727.72, profit: 40045.0, time: 5047.644, distance: 2798.0, weight: 25745.0, best_fitness: 376157.666,
# Name:ga_best_candidate, Generatia: 10, score: 12173.208, profit: 35069.0, time: 4081.246, distance: 2798.0, weight: 23069.0, best_fitness: 355067.888,
# Name:ga_best_candidate, Generatia: 11, score: 13392.093, profit: 40910.0, time: 4905.153, distance: 2798.0, weight: 25910.0, best_fitness: 361979.517,
# Name:ga_best_candidate, Generatia: 12, score: 14106.129, profit: 37760.0, time: 4216.376, distance: 2819.0, weight: 25360.0, best_fitness: 296580.742,
# Name:ga_best_candidate, Generatia: 13, score: 14515.216, profit: 39007.0, time: 4365.737, distance: 2676.0, weight: 25907.0, best_fitness: 308575.193,
# Name:ga_best_candidate, Generatia: 14, score: 14515.216, profit: 39007.0, time: 4365.737, distance: 2676.0, weight: 25907.0, best_fitness: 271067.25,
# Name:ga_best_candidate, Generatia: 15, score: 14520.813, profit: 38526.0, time: 4278.999, distance: 2798.0, weight: 24526.0, best_fitness: 125341.668,
# Name:ga_best_candidate, Generatia: 16, score: 14658.178, profit: 40846.0, time: 4668.061, distance: 2798.0, weight: 25846.0, best_fitness: 143354.287,
# Name:ga_best_candidate, Generatia: 17, score: 15059.553, profit: 40544.0, time: 4542.682, distance: 2798.0, weight: 25744.0, best_fitness: 102810.415,
# Name:ga_best_candidate, Generatia: 18, score: 15234.507, profit: 40149.0, time: 4441.086, distance: 2798.0, weight: 25349.0, best_fitness: 55212.227,
# Name:ga_best_candidate, Generatia: 19, score: 15579.831, profit: 40553.0, time: 4451.545, distance: 2798.0, weight: 25753.0, best_fitness: 88916.871,
# Name:ga_best_candidate, Generatia: 20, score: 15597.424, profit: 40847.0, time: 4500.816, distance: 2798.0, weight: 25747.0, best_fitness: 40045.741,
# Name:ga_best_candidate, Generatia: 21, score: 15803.624, profit: 41049.0, time: 4500.067, distance: 2798.0, weight: 25849.0, best_fitness: 40718.094,
# Name:ga_best_candidate, Generatia: 22, score: 16284.58, profit: 40732.0, time: 4357.829, distance: 2798.0, weight: 25732.0, best_fitness: 25294.319,
# Name:ga_best_candidate, Generatia: 23, score: 16404.581, profit: 40904.0, time: 4367.098, distance: 2798.0, weight: 25804.0, best_fitness: 44276.873,
# Name:ga_best_candidate, Generatia: 24, score: 16505.075, profit: 41115.0, time: 4386.796, distance: 2798.0, weight: 25915.0, best_fitness: 33065.549,
# Name:ga_best_candidate, Generatia: 25, score: 16560.938, profit: 40773.0, time: 4315.876, distance: 2798.0, weight: 25673.0, best_fitness: 36919.354,
# Name:ga_best_candidate, Generatia: 26, score: 16598.581, profit: 40802.0, time: 4314.335, distance: 2798.0, weight: 25702.0, best_fitness: 38202.699,
# Name:ga_best_candidate, Generatia: 27, score: 16754.472, profit: 40800.0, time: 4286.19, distance: 2798.0, weight: 25700.0, best_fitness: 24692.508,
# Name:ga_best_candidate, Generatia: 28, score: 16754.472, profit: 40800.0, time: 4286.19, distance: 2798.0, weight: 25700.0, best_fitness: 36913.625,
# Name:ga_best_candidate, Generatia: 29, score: 16754.472, profit: 40800.0, time: 4286.19, distance: 2798.0, weight: 25700.0, best_fitness: 28063.623,
# Name:ga_best_candidate, Generatia: 30, score: 16754.472, profit: 40800.0, time: 4286.19, distance: 2798.0, weight: 25700.0, best_fitness: 43115.084,
# Name:ga_best_candidate, Generatia: 31, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 490267.285,
# Name:ga_best_candidate, Generatia: 32, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 27073.567,
# Name:ga_best_candidate, Generatia: 33, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 30122.645,
# Name:ga_best_candidate, Generatia: 34, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 24111.583,
# Name:ga_best_candidate, Generatia: 35, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 29515.28,
# Name:ga_best_candidate, Generatia: 36, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 94167.686,
# Name:ga_best_candidate, Generatia: 37, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 26955.097,
# Name:ga_best_candidate, Generatia: 38, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 27331.23,
# Name:ga_best_candidate, Generatia: 39, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 36285.502,
# Name:ga_best_candidate, Generatia: 40, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 30261.222,
# Name:ga_best_candidate, Generatia: 41, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 138580.757,
# Name:ga_best_candidate, Generatia: 42, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 117551.288,
# Name:ga_best_candidate, Generatia: 43, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 42743.269,
# Name:ga_best_candidate, Generatia: 44, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 20599.575,
# Name:ga_best_candidate, Generatia: 45, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 30006.581,
# Name:ga_best_candidate, Generatia: 46, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 20528.116,
# Name:ga_best_candidate, Generatia: 47, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 33278.95,
# Name:ga_best_candidate, Generatia: 48, score: 16860.367, profit: 40825.0, time: 4271.771, distance: 2798.0, weight: 25825.0, best_fitness: 60255.377,
# Name:ga_best_candidate, Generatia: 49, score: 16879.036, profit: 40483.0, time: 4207.48, distance: 2798.0, weight: 25583.0, best_fitness: 64979.574,
# Name:ga_best_candidate, Generatia: 50, score: 16931.966, profit: 40565.0, time: 4212.662, distance: 2798.0, weight: 25665.0, best_fitness: 39626.251,
# Name:ga_best_candidate, Generatia: 51, score: 16931.966, profit: 40565.0, time: 4212.662, distance: 2798.0, weight: 25665.0, best_fitness: 18148.763,
# Name:ga_best_candidate, Generatia: 52, score: 16931.966, profit: 40565.0, time: 4212.662, distance: 2798.0, weight: 25665.0, best_fitness: 43454.074,
# Name:ga_best_candidate, Generatia: 53, score: 16968.458, profit: 40905.0, time: 4266.763, distance: 2798.0, weight: 25905.0, best_fitness: 31591.11,
# Name:ga_best_candidate, Generatia: 54, score: 16968.458, profit: 40905.0, time: 4266.763, distance: 2798.0, weight: 25905.0, best_fitness: 65002.671,
# Name:ga_best_candidate, Generatia: 55, score: 16993.374, profit: 40563.0, time: 4201.359, distance: 2798.0, weight: 25663.0, best_fitness: 21561.333,
# Name:ga_best_candidate, Generatia: 56, score: 16993.374, profit: 40563.0, time: 4201.359, distance: 2798.0, weight: 25663.0, best_fitness: 29484.261,
# Name:ga_best_candidate, Generatia: 57, score: 16993.374, profit: 40563.0, time: 4201.359, distance: 2798.0, weight: 25663.0, best_fitness: 37524.926,
# Name:ga_best_candidate, Generatia: 58, score: 16993.374, profit: 40563.0, time: 4201.359, distance: 2798.0, weight: 25663.0, best_fitness: 21981.696,
# Name:ga_best_candidate, Generatia: 59, score: 16993.374, profit: 40563.0, time: 4201.359, distance: 2798.0, weight: 25663.0, best_fitness: 38340.488,
# Name:ga_best_candidate, Generatia: 60, score: 16993.374, profit: 40563.0, time: 4201.359, distance: 2798.0, weight: 25663.0, best_fitness: 24289.456,
# Name:ga_best_candidate, Generatia: 61, score: 17008.92, profit: 40621.0, time: 4208.927, distance: 2798.0, weight: 25721.0, best_fitness: 25851.449,
# Name:ga_best_candidate, Generatia: 62, score: 17008.92, profit: 40621.0, time: 4208.927, distance: 2798.0, weight: 25721.0, best_fitness: 67350.41,
# Name:ga_best_candidate, Generatia: 63, score: 17061.322, profit: 40458.0, time: 4170.531, distance: 2798.0, weight: 25658.0, best_fitness: 326816.898,
# Name:ga_best_candidate, Generatia: 64, score: 17061.322, profit: 40458.0, time: 4170.531, distance: 2798.0, weight: 25658.0, best_fitness: 26035.504,
# Name:ga_best_candidate, Generatia: 65, score: 17061.322, profit: 40458.0, time: 4170.531, distance: 2798.0, weight: 25658.0, best_fitness: 27035.86,
# Name:ga_best_candidate, Generatia: 66, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 34560.389,
# Name:ga_best_candidate, Generatia: 67, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 111132.943,
# Name:ga_best_candidate, Generatia: 68, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 30402.332,
# Name:ga_best_candidate, Generatia: 69, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 42716.722,
# Name:ga_best_candidate, Generatia: 70, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 40848.653,
# Name:ga_best_candidate, Generatia: 71, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 35851.848,
# Name:ga_best_candidate, Generatia: 72, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 29635.431,
# Name:ga_best_candidate, Generatia: 73, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 43265.14,
# Name:ga_best_candidate, Generatia: 74, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 42756.076,
# Name:ga_best_candidate, Generatia: 75, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 33983.488,
# Name:ga_best_candidate, Generatia: 76, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 32545.301,
# Name:ga_best_candidate, Generatia: 77, score: 17078.108, profit: 40516.0, time: 4177.877, distance: 2798.0, weight: 25716.0, best_fitness: 38115.778,
# Name:ga_best_candidate, Generatia: 78, score: 17078.108, profit: 40516.0, time: 4177.877, distance: 2798.0, weight: 25716.0, best_fitness: 33440.342,
# Name:ga_best_candidate, Generatia: 79, score: 17078.108, profit: 40516.0, time: 4177.877, distance: 2798.0, weight: 25716.0, best_fitness: 223642.154,
# Name:ga_best_candidate, Generatia: 80, score: 17078.108, profit: 40516.0, time: 4177.877, distance: 2798.0, weight: 25716.0, best_fitness: 26892.753,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_best_candidate, Generatia: 81, score: 17078.108, profit: 40516.0, time: 4177.877, distance: 2798.0, weight: 25716.0, best_fitness: 39555.697,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_best_candidate, Generatia: 82, score: 17078.108, profit: 40516.0, time: 4177.877, distance: 2798.0, weight: 25716.0, best_fitness: 685433.971,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_best_candidate, Generatia: 83, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 568077.718,
# Hybrid mixed TTP population = (400, 2, (280, 280))
# Name:ga_best_candidate, Generatia: 84, score: 17076.512, profit: 40516.0, time: 4178.162, distance: 2798.0, weight: 25716.0, best_fitness: 696960.508,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 20
#      17 print(cfg["description"])
#      18 print("GA params:", {k: cfg[k] for k in ["population_size", "generations", "mutation_rate", "crossover_rate"]})
# ---> 20 best_individ = ttp()
#      21 best_individ
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\GeneticAlgorithmManager\my_code\algoritm_genetic.py:111, in GeneticAlgorithm.__call__(self)
#     109 scores = self.metrics.getScore(self.__genoms, fitness_values)
#     110 # adaugare stres in populatie atunci cand lipseste progresul
# --> 111 self.stres(self.__genoms, scores)
#     112 # afisare metrici
#     113 self.showMetrics(generation, scores)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\GeneticAlgorithmManager\my_code\stres.py:15, in Stres.__call__(self, genoms, scores)
#      14 def __call__(self, genoms, scores):
# ---> 15     return self._extern_fn(genoms, scores)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\stres\my_code\stres_ttp_MATEI.py:400, in StresTTP.__call__(self, genoms, scores)
#     397     self._shake_population(genoms, scores)
#     398 else:
#     399     # Strong plateau ⇒ partial restart using hybrid init.
# --> 400     self._partial_restart(genoms, scores)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\stres\my_code\stres_ttp_MATEI.py:255, in StresTTP._partial_restart(self, genoms, scores)
#     252     return
#     254 # 1) create full new population via hybrid init
# --> 255 self.init_population(n, genoms)
#     256 pop_new = genoms.population()
#     258 # 2) overwrite the first len(keep_idx) individuals with the kept ones
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\init_population\my_code\init_hybrid_population_MATEI.py:49, in InitPopulationHybrid.__call__(self, size, genoms)
#      48 def __call__(self, size, genoms=None):
# ---> 49     self.__fn(size, genoms=genoms, **self.__configs)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\init_population\my_code\init_hybrid_population_MATEI.py:118, in InitPopulationHybrid.initPopulationHybrid(self, size, genoms, lambda_time, vmax, vmin, Wmax, seed)
#     115     r = tabu2(None, None, r)  # tabu 2-opt
#     117 elif choice < 0.90:
# --> 118     r = vnd(None, None, r)    # simple VND
#     120 else:
#     121     # Forced diversity
#     122     r = np.random.permutation(self.GENOME_LENGTH)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\vnd.py:68, in VND.__call__(self, p1, p2, route, **call_cfg)
#      66     new_route = op.twoOptLS(cur)
#      67 else:
# ---> 68     new_route = op(p1, p2, cur)
#      70 new_len = self._route_len(new_route, dist)
#      72 if new_len + 1e-12 < cur_len:
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\three_opt.py:60, in ThreeOpt.__call__(self, p1, p2, route, **call_configs)
#      58 cfg = dict(self.__configs)
#      59 cfg.update(call_configs)
# ---> 60 return self.__fn(p1, p2, route, **cfg)
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\three_opt.py:136, in ThreeOpt.threeOptRestrict(self, p1, p2, route, iters, k_candidates, sample_i, seed)
#     133 if not (j+1 < k < n-1):
#     134     continue
# --> 136 new_r, new_len = self._best_3opt_reconnect(cur, i, j, k)
#     137 if new_len + 1e-9 < cur_len:
#     138     cur = new_r
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\three_opt.py:98, in ThreeOpt._best_3opt_reconnect(self, r, i, j, k)
#      96 best_len = self._route_length(r)
#      97 for rr in cands:
# ---> 98     ll = self._route_length(rr)
#      99     if ll < best_len:
#     100         best_len = ll
#
# File c:\Users\Matei\MLProjects\UAIC-MIAO1\Sem-1\Metode-inspirate-din-natura\Homeworks\MIN\extension\local_search_algorithms\three_opt.py:73, in ThreeOpt._route_length(self, r)
#      72 def _route_length(self, r):
# ---> 73     return self.distance[r[-1], r[0]] + np.sum(self.distance[r[:-1], r[1:]])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\fromnumeric.py:2333, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2327         raise ValueError("Passing `min` or `max` keyword argument when "
#    2328                          "`a_min` and `a_max` are provided is forbidden.")
#    2330     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2333 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2334                     initial=None, where=None):
#    2335     return (a, out)
#    2338 @array_function_dispatch(_sum_dispatcher)
#    2339 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2340         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:
